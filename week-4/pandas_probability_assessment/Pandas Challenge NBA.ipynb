# %%
import json
import pandas as pd

# %% [markdown]
# # Part 1: Reading and investigating data
#
# Open up the `player_data.json` and investigate the data structure.

# %%
with open("player_data.json", "r") as read_file:
    data = json.load(read_file)

# %% [markdown]
# # Part 2:  Creating the Dataframe
#
# Create a data frame where each row corresponds to a game for each player. You must have atleast the following columns in your final dataframe:
#
# 'DISPLAY_FIRST_LAST', 'PERSON_ID', 'TEAM_ID', 'AST', 'BLK','Game_ID',  'MIN', 'PTS', 'REB', 'TEAM_ABBREVIATION', 'STL'
#
# *You can include additional columns in your dataframe, so you don't have to do additional work to remove other columns.*

# %%
df = pd.DataFrame()

for person in data:
    # ignore the players who never played a game
    if len(person['GAMELOG']) == 0:
        continue
        
    # create one data frame with just the player's name, id, and team_id (if there)
    df1 = pd.DataFrame(person, columns=['DISPLAY_FIRST_LAST', 'PERSON_ID', 'TEAM_ID'], index=[0])
    
    # creates another df with each game as a row
    df2 = pd.DataFrame(person['GAMELOG'])
    
    # does an outer join to put the player name, player id, team id on each game row
    merged = pd.merge(df1, df2, left_on='PERSON_ID', right_on='Player_ID', how='outer')
    
    # add all those games to the main df which will contain all the games with the player
    # that row belongs to right next to them
    df = pd.concat([df, merged])
    
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Part 3: Pandas Questions
#
# Answer the following questions

# %% [markdown]
# ## 1
# - Find the player who scored the most points in an individual game last season.
#
# -  Now do the same for rebounds, blocks, and assists.

# %%
df.columns
# Out:
# Index(['DISPLAY_FIRST_LAST', 'PERSON_ID', 'TEAM_ID_x', 'AST', 'BLK', 'DREB',
#        'FG3A', 'FG3M', 'FG3_PCT', 'FGA', 'FGM', 'FG_PCT', 'FTA', 'FTM',
#        'FT_PCT', 'GAME_DATE', 'Game_ID', 'MATCHUP', 'MIN', 'OREB', 'PF',
#        'PLUS_MINUS', 'PTS', 'Player_ID', 'REB', 'SEASON_ID', 'STL',
#        'TEAM_ABBREVIATION', 'TEAM_ID_y', 'TOV', 'VIDEO_AVAILABLE', 'WL'],
#       dtype='object')

# %%
df.set_index(Player_ID)
# Out:
#       DISPLAY_FIRST_LAST  PERSON_ID   TEAM_ID_x  AST  BLK  DREB  FG3A  FG3M  \
# 0           Alex Abrines     203518           0    0    0     0     1     0
# 1           Alex Abrines     203518           0    0    0     1     2     1
# 2           Alex Abrines     203518           0    0    2     1     5     1
# 3           Alex Abrines     203518           0    0    0     1     4     2
# 4           Alex Abrines     203518           0    1    0     1     7     3
# 5           Alex Abrines     203518           0    0    0     1     3     2
# 6           Alex Abrines     203518           0    0    0     4     2     0
# 7           Alex Abrines     203518           0    0    0     0     1     0
# 8           Alex Abrines     203518           0    2    0     1     5     1
# 9           Alex Abrines     203518           0    0    0     3     1     0
# 10          Alex Abrines     203518           0    1    0     3     4     1
# 11          Alex Abrines     203518           0    1    0     1     2     0
# 12          Alex Abrines     203518           0    1    0     1     2     0
# 13          Alex Abrines     203518           0    1    0     2    11     7
# 14          Alex Abrines     203518           0    1    0     2     8     1
# 15          Alex Abrines     203518           0    1    0     1     2     0
# 16          Alex Abrines     203518           0    0    0     0     1     0
# 17          Alex Abrines     203518           0    0    0     0     1     0
# 18          Alex Abrines     203518           0    2    1     2     6     2
# 19          Alex Abrines     203518           0    0    0     2     4     2
# 20          Alex Abrines     203518           0    0    0     3     3     0
# 21          Alex Abrines     203518           0    0    0     0    10     3
# 22          Alex Abrines     203518           0    3    0     4     2     1
# 23          Alex Abrines     203518           0    2    2     1     7     2
# 24          Alex Abrines     203518           0    0    0     2    10     5
# 25          Alex Abrines     203518           0    0    1     0     1     1
# 26          Alex Abrines     203518           0    0    0     1     3     0
# 27          Alex Abrines     203518           0    1    0     1     5     2
# 28          Alex Abrines     203518           0    2    0     1     1     0
# 29          Alex Abrines     203518           0    1    0     1     7     2
# ...                  ...        ...         ...  ...  ...   ...   ...   ...
# 26071        Ivica Zubac    1627826  1610612746    3    0     0     0     0
# 26072        Ivica Zubac    1627826  1610612746    0    4    11     0     0
# 26073        Ivica Zubac    1627826  1610612746    1    0     4     0     0
# 26074        Ivica Zubac    1627826  1610612746    0    1     4     0     0
# 26075        Ivica Zubac    1627826  1610612746    1    1     5     0     0
# 26076        Ivica Zubac    1627826  1610612746    1    0     6     0     0
# 26077        Ivica Zubac    1627826  1610612746    1    0     3     0     0
# 26078        Ivica Zubac    1627826  1610612746    0    2     2     0     0
# 26079        Ivica Zubac    1627826  1610612746    1    1     3     0     0
# 26080        Ivica Zubac    1627826  1610612746    1    0     6     0     0
# 26081        Ivica Zubac    1627826  1610612746    0    0     1     0     0
# 26082        Ivica Zubac    1627826  1610612746    0    0     6     0     0
# 26083        Ivica Zubac    1627826  1610612746    2    1     4     0     0
# 26084        Ivica Zubac    1627826  1610612746    1    1     1     0     0
# 26085        Ivica Zubac    1627826  1610612746    3    1     0     0     0
# 26086        Ivica Zubac    1627826  1610612746    0    1     3     0     0
# 26087        Ivica Zubac    1627826  1610612746    2    2     8     0     0
# 26088        Ivica Zubac    1627826  1610612746    1    4     3     0     0
# 26089        Ivica Zubac    1627826  1610612746    0    2     9     0     0
# 26090        Ivica Zubac    1627826  1610612746    1    1     0     0     0
# 26091        Ivica Zubac    1627826  1610612746    1    0     2     0     0
# 26092        Ivica Zubac    1627826  1610612746    0    0     1     0     0
# 26093        Ivica Zubac    1627826  1610612746    0    1     2     0     0
# 26094        Ivica Zubac    1627826  1610612746    0    0     1     0     0
# 26095        Ivica Zubac    1627826  1610612746    0    1     1     0     0
# 26096        Ivica Zubac    1627826  1610612746    0    0     1     0     0
# 26097        Ivica Zubac    1627826  1610612746    1    0     4     0     0
# 26098        Ivica Zubac    1627826  1610612746    0    0     4     0     0
# 26099        Ivica Zubac    1627826  1610612746    1    0     1     0     0
# 26100        Ivica Zubac    1627826  1610612746    0    1     0     0     0
#
#        FG3_PCT  FGA  ...  PTS  Player_ID  REB  SEASON_ID  STL  \
# 0        0.000    2  ...    0     203518    0      22018    0
# 1        0.500    2  ...    3     203518    1      22018    0
# 2        0.200    6  ...    7     203518    1      22018    0
# 3        0.500    4  ...    6     203518    1      22018    0
# 4        0.429    7  ...    9     203518    1      22018    0
# 5        0.667    4  ...    8     203518    3      22018    1
# 6        0.000    4  ...    6     203518    4      22018    0
# 7        0.000    1  ...    0     203518    0      22018    0
# 8        0.200    6  ...    5     203518    1      22018    1
# 9        0.000    2  ...    0     203518    3      22018    1
# 10       0.250    4  ...    3     203518    3      22018    0
# 11       0.000    2  ...    0     203518    1      22018    3
# 12       0.000    3  ...    2     203518    1      22018    0
# 13       0.636   11  ...   21     203518    2      22018    0
# 14       0.125    9  ...    3     203518    3      22018    0
# 15       0.000    2  ...    0     203518    1      22018    0
# 16       0.000    1  ...    0     203518    0      22018    0
# 17       0.000    2  ...    0     203518    0      22018    0
# 18       0.333    6  ...    8     203518    2      22018    2
# 19       0.500    6  ...    6     203518    2      22018    0
# 20       0.000    3  ...    0     203518    4      22018    1
# 21       0.300   12  ...    9     203518    0      22018    1
# 22       0.500    4  ...    7     203518    4      22018    0
# 23       0.286    8  ...    8     203518    1      22018    0
# 24       0.500   15  ...   25     203518    2      22018    0
# 25       1.000    2  ...    3     203518    0      22018    4
# 26       0.000    5  ...    2     203518    1      22018    2
# 27       0.400    5  ...    6     203518    1      22018    0
# 28       0.000    1  ...    0     203518    1      22018    0
# 29       0.286   10  ...   10     203518    2      22018    1
# ...        ...  ...  ...  ...        ...  ...        ...  ...
# 26071    0.000    5  ...    7    1627826    2      22018    0
# 26072    0.000   16  ...   24    1627826   16      22018    0
# 26073    0.000   12  ...   10    1627826    8      22018    0
# 26074    0.000    8  ...   18    1627826    4      22018    0
# 26075    0.000    6  ...   17    1627826    7      22018    0
# 26076    0.000   14  ...   26    1627826   12      22018    0
# 26077    0.000    2  ...    7    1627826    3      22018    0
# 26078    0.000    3  ...    5    1627826    2      22018    0
# 26079    0.000   10  ...   10    1627826    5      22018    0
# 26080    0.000    8  ...   11    1627826    9      22018    1
# 26081    0.000    2  ...    4    1627826    2      22018    0
# 26082    0.000    6  ...    9    1627826    8      22018    0
# 26083    0.000    6  ...   10    1627826    6      22018    0
# 26084    0.000    4  ...    8    1627826    2      22018    0
# 26085    0.000    8  ...    7    1627826    2      22018    0
# 26086    0.000    8  ...    6    1627826    5      22018    0
# 26087    0.000   10  ...   18    1627826   11      22018    0
# 26088    0.000   12  ...   19    1627826    4      22018    0
# 26089    0.000   10  ...   16    1627826   11      22018    2
# 26090    0.000    1  ...    0    1627826    0      22018    0
# 26091    0.000    2  ...    4    1627826    2      22018    0
# 26092    0.000    4  ...    6    1627826    1      22018    0
# 26093    0.000    0  ...    0    1627826    2      22018    0
# 26094    0.000    0  ...    0    1627826    1      22018    0
# 26095    0.000    2  ...    0    1627826    2      22018    0
# 26096    0.000    2  ...    0    1627826    2      22018    0
# 26097    0.000    3  ...    5    1627826    6      22018    0
# 26098    0.000    5  ...    9    1627826    8      22018    1
# 26099    0.000    1  ...    0    1627826    2      22018    0
# 26100    0.000    1  ...    0    1627826    1      22018    0
#
#       TEAM_ABBREVIATION   TEAM_ID_y TOV  VIDEO_AVAILABLE  WL
# 0                   OKC  1610612760   0                1   W
# 1                   OKC  1610612760   0                1   W
# 2                   OKC  1610612760   0                1   L
# 3                   OKC  1610612760   0                1   W
# 4                   OKC  1610612760   0                1   W
# 5                   OKC  1610612760   0                1   W
# 6                   OKC  1610612760   0                1   W
# 7                   OKC  1610612760   1                1   L
# 8                   OKC  1610612760   0                1   L
# 9                   OKC  1610612760   2                1   W
# 10                  OKC  1610612760   1                1   L
# 11                  OKC  1610612760   1                1   W
# 12                  OKC  1610612760   1                1   W
# 13                  OKC  1610612760   0                1   W
# 14                  OKC  1610612760   0                1   W
# 15                  OKC  1610612760   0                1   L
# 16                  OKC  1610612760   0                1   W
# 17                  OKC  1610612760   1                1   W
# 18                  OKC  1610612760   1                1   W
# 19                  OKC  1610612760   1                1   L
# 20                  OKC  1610612760   1                1   W
# 21                  OKC  1610612760   0                1   W
# 22                  OKC  1610612760   1                1   W
# 23                  OKC  1610612760   0                1   W
# 24                  OKC  1610612760   0                1   W
# 25                  OKC  1610612760   1                1   W
# 26                  OKC  1610612760   0                1   W
# 27                  OKC  1610612760   0                1   L
# 28                  OKC  1610612760   0                1   L
# 29                  OKC  1610612760   2                1   L
# ...                 ...         ...  ..              ...  ..
# 26071               LAL  1610612747   2                1   L
# 26072               LAL  1610612747   2                1   W
# 26073               LAL  1610612747   4                1   L
# 26074               LAL  1610612747   2                1   L
# 26075               LAL  1610612747   0                1   L
# 26076               LAL  1610612747   4                1   W
# 26077               LAL  1610612747   0                1   W
# 26078               LAL  1610612747   0                1   L
# 26079               LAL  1610612747   0                1   L
# 26080               LAL  1610612747   0                1   W
# 26081               LAL  1610612747   1                1   W
# 26082               LAL  1610612747   2                1   L
# 26083               LAL  1610612747   1                1   L
# 26084               LAL  1610612747   1                1   L
# 26085               LAL  1610612747   2                1   L
# 26086               LAL  1610612747   1                1   L
# 26087               LAL  1610612747   1                1   W
# 26088               LAL  1610612747   1                1   L
# 26089               LAL  1610612747   1                1   W
# 26090               LAL  1610612747   0                1   L
# 26091               LAL  1610612747   0                1   L
# 26092               LAL  1610612747   0                1   W
# 26093               LAL  1610612747   0                1   W
# 26094               LAL  1610612747   0                1   W
# 26095               LAL  1610612747   1                1   L
# 26096               LAL  1610612747   0                1   W
# 26097               LAL  1610612747   1                1   L
# 26098               LAL  1610612747   2                1   W
# 26099               LAL  1610612747   0                1   W
# 26100               LAL  1610612747   0                1   L
#
# [26101 rows x 32 columns]

# %%
stats = ['PTS', 'REB', 'BLK', 'AST']
for stat in stats:
    print(stat, ':', df.loc[df[stat].idxmax()][0])
# Out:
# PTS : James Harden
# REB : Karl-Anthony Towns
# BLK : Mitchell Robinson
# AST : Russell Westbrook

# %% [markdown]
# ## 2:
#
# - Find the player who scored the most points for the entire season.
#
# - Now do the same for rebounds, blocks, and assists.

# %%
stats = ['PTS', 'REB', 'BLK', 'AST']
for stat in stats:
    # get max stat
    #most = df.groupby(['PERSON_ID'])[stat].sum().max()
    
    # find player with max stat
    player = df.groupby(['DISPLAY_FIRST_LAST'])[stat].sum().idxmax()    
    
    print(stat, ":", player, '\n')
# Out:
# PTS : James Harden
#
# REB : Andre Drummond
#
# BLK : Myles Turner
#
# AST : Russell Westbrook

# %% [markdown]
# ## 3:
# How many players played in at least 82 games last season?

# %%
game_count = df.groupby('DISPLAY_FIRST_LAST').PERSON_ID.count()

game_count[(game_count>=82)].count()
# Out:
# 21

# %% [markdown]
# ## 4:
# - Find which team scored the most points for the entire season.
#
# - Now do the same for rebounds, blocks, and assists.

# %%
for stat in stats:
    team_sums = df.groupby(['TEAM_ABBREVIATION'])[stat].sum()
    most = team_sums.idxmax()
    print(stat,":", most)
# Out:
# PTS : MIL
# REB : MIL
# BLK : GSW
# AST : GSW

# %% [markdown]
# ## 5:
# Which team had the most players play for them last season?

# %%
players_per_team = df.groupby(['TEAM_ABBREVIATION']).nunique()
num_players_per_team = players_per_team['PERSON_ID']
num_players_per_team.idxmax()
# Out:
# 'MEM'

# %% [markdown]
# ## 6:
# - How many players play for more than one team last year?
#
# - What is the most number of teams a player played for last season?

# %%
#86 players did
players_on_1plus_teams = df.groupby(['PERSON_ID', 'DISPLAY_FIRST_LAST']).nunique()[(df.groupby(['PERSON_ID', 'DISPLAY_FIRST_LAST']).nunique()['TEAM_ABBREVIATION'] > 1)]
players_on_1plus_teams
#3 is the max
# players_on_1plus_teams['TEAM_ABBREVIATION'].max()
# Out:
#                                    DISPLAY_FIRST_LAST  PERSON_ID  TEAM_ID_x  \
# PERSON_ID DISPLAY_FIRST_LAST
# 2199      Tyson Chandler                            1          1          1
# 2200      Pau Gasol                                 1          1          1
# 2594      Kyle Korver                               1          1          1
# 2772      Trevor Ariza                              1          1          1
# 101139    CJ Miles                                  1          1          1
# 201147    Corey Brewer                              1          1          1
# 201160    Jason Smith                               1          1          1
# 201163    Wilson Chandler                           1          1          1
# 201188    Marc Gasol                                1          1          1
# 201583    Ryan Anderson                             1          1          1
# 201584    Courtney Lee                              1          1          1
# 201588    George Hill                               1          1          1
# 201599    DeAndre Jordan                            1          1          1
# 201961    Wayne Ellington                           1          1          1
# 202066    Garrett Temple                            1          1          1
# 202083    Wesley Matthews                           1          1          1
# 202325    Wesley Johnson                            1          1          1
# 202328    Greg Monroe                               1          1          1
# 202340    Avery Bradley                             1          1          1
# 202391    Jeremy Lin                                1          1          1
# 202683    Enes Kanter                               1          1          1
# 202685    Jonas Valanciunas                         1          1          1
# 202688    Brandon Knight                            1          1          1
# 202692    Alec Burks                                1          1          1
# 202693    Markieff Morris                           1          1          1
# 202697    Iman Shumpert                             1          1          1
# 202699    Tobias Harris                             1          1          1
# 202702    Kenneth Faried                            1          1          1
# 202703    Nikola Mirotic                            1          1          1
# 202710    Jimmy Butler                              1          1          1
# ...                                               ...        ...        ...
# 204025    Tim Frazier                               1          1          1
# 1626150   Andrew Harrison                           1          1          1
# 1626153   Delon Wright                              1          1          1
# 1626155   Sam Dekker                                1          1          1
# 1626162   Kelly Oubre Jr.                           1          1          1
# 1626166   Cameron Payne                             1          1          1
# 1626169   Stanley Johnson                           1          1          1
# 1626171   Bobby Portis                              1          1          1
# 1626174   Christian Wood                            1          1          1
# 1626246   Boban Marjanovic                          1          1          1
# 1627737   Marquese Chriss                           1          1          1
# 1627740   Henry Ellenson                            1          1          1
# 1627746   Skal Labissiere                           1          1          1
# 1627748   Thon Maker                                1          1          1
# 1627758   Ron Baker                                 1          1          1
# 1627775   Patrick McCaw                             1          1          1
# 1627782   Wayne Selden                              1          1          1
# 1627789   Timothe Luwawu-Cabarrot                   1          1          1
# 1627826   Ivica Zubac                               1          1          1
# 1628249   Mitchell Creek                            1          1          1
# 1628372   Dennis Smith Jr.                          1          1          1
# 1628382   Justin Jackson                            1          1          1
# 1628393   Jawun Evans                               1          1          1
# 1628403   Caleb Swanigan                            1          1          1
# 1628416   Tyler Dorsey                              1          1          1
# 1629004   Svi Mykhailiuk                            1          1          1
# 1629013   Landry Shamet                             1          1          1
# 1629034   Ray Spalding                              1          1          1
# 1629150   Emanuel Terry                             1          1          1
# 1629168   BJ Johnson                                1          1          1
#
#                                    AST  BLK  DREB  FG3A  FG3M  FG3_PCT  FGA  \
# PERSON_ID DISPLAY_FIRST_LAST
# 2199      Tyson Chandler             4    4    12     2     1        1    8
# 2200      Pau Gasol                  7    4    11     3     2        3    9
# 2594      Kyle Korver                5    3     7    12     7       21   15
# 2772      Trevor Ariza              11    3    12    13     8       20   16
# 101139    CJ Miles                   5    3     5    11     6       15   14
# 201147    Corey Brewer               4    3     5     6     4        6   11
# 201160    Jason Smith                4    3     5     5     3        4    6
# 201163    Wilson Chandler            6    4    10     8     6       10   11
# 201188    Marc Gasol                12    7    15     9     6       13   18
# 201583    Ryan Anderson              4    2     7     6     3        5    9
# 201584    Courtney Lee               6    2     6     7     4        5   11
# 201588    George Hill                8    2     7     8     4        9   14
# 201599    DeAndre Jordan             8    6    18     1     1        1   11
# 201961    Wayne Ellington            5    3     6    14     8       22   17
# 202066    Garrett Temple             6    4     8     9     6       15   14
# 202083    Wesley Matthews            6    3     6    12     8       22   16
# 202325    Wesley Johnson             4    2     7     6     4        8    8
# 202328    Greg Monroe                4    3     9     2     2        2   12
# 202340    Avery Bradley              8    3     7     9     5       14   17
# 202391    Jeremy Lin                10    3     7     8     5       11   14
# 202683    Enes Kanter                7    5    13     4     3        4   16
# 202685    Jonas Valanciunas          6    5    14     4     3        5   18
# 202688    Brandon Knight             7    2     5     8     4       10   13
# 202692    Alec Burks                 8    4    10     8     5       12   18
# 202693    Markieff Morris            6    3     9    10     6       15   17
# 202697    Iman Shumpert              7    3     8    10     6       14   14
# 202699    Tobias Harris             10    4    13     9     7       17   17
# 202702    Kenneth Faried             4    4    11     4     3        4   14
# 202703    Nikola Mirotic             4    4    13    12     7       22   17
# 202710    Jimmy Butler               9    3     9     9     7       13   20
# ...                                ...  ...   ...   ...   ...      ...  ...
# 204025    Tim Frazier               14    2     8     7     4        7   13
# 1626150   Andrew Harrison            6    2     4     5     2        5    8
# 1626153   Delon Wright              13    3    11     7     4        9   16
# 1626155   Sam Dekker                 5    2     7     6     3        6   14
# 1626162   Kelly Oubre Jr.            6    4     9     9     6       21   17
# 1626166   Cameron Payne              8    2     6     8     5        9   14
# 1626169   Stanley Johnson            5    3     8    10     5       16   15
# 1626171   Bobby Portis               6    3    10    10     6       10   16
# 1626174   Christian Wood             4    3     8     5     3        6   13
# 1626246   Boban Marjanovic           6    4    10     4     3        4   12
# 1627737   Marquese Chriss            3    3     7     7     4        9   12
# 1627740   Henry Ellenson             4    2    10     7     4        6   10
# 1627746   Skal Labissiere            3    2     7     4     3        4    6
# 1627748   Thon Maker                 5    5     8     8     5       10   10
# 1627758   Ron Baker                  5    2     4     4     2        2    4
# 1627775   Patrick McCaw              4    2     4     5     3        4    8
# 1627782   Wayne Selden               6    3     9     7     5        8   16
# 1627789   Timothe Luwawu-Cabarrot    5    3     9     9     5       12   14
# 1627826   Ivica Zubac                5    5    11     1     1        1   17
# 1628249   Mitchell Creek             3    1     3     2     1        1    3
# 1628372   Dennis Smith Jr.          12    3     9     9     4       13   18
# 1628382   Justin Jackson             6    3     8     9     6       16   16
# 1628393   Jawun Evans                4    1     5     2     1        1    5
# 1628403   Caleb Swanigan             3    2     7     3     2        2    7
# 1628416   Tyler Dorsey               6    2     7    10     5       12   15
# 1629004   Svi Mykhailiuk             5    2     5     8     4        8   11
# 1629013   Landry Shamet              7    2     7    12     8       20   13
# 1629034   Ray Spalding               3    4     6     2     1        1    7
# 1629150   Emanuel Terry              2    1     3     1     1        1    3
# 1629168   BJ Johnson                 1    1     4     4     2        2    5
#
#                                    ...  PTS  Player_ID  REB  SEASON_ID  STL  \
# PERSON_ID DISPLAY_FIRST_LAST       ...
# 2199      Tyson Chandler           ...   12          1   15          1    3
# 2200      Pau Gasol                ...   14          1   11          1    2
# 2594      Kyle Korver              ...   21          1    8          1    3
# 2772      Trevor Ariza             ...   22          1   13          1    6
# 101139    CJ Miles                 ...   14          1    7          1    4
# 201147    Corey Brewer             ...   12          1    8          1    5
# 201160    Jason Smith              ...    9          1    7          1    2
# 201163    Wilson Chandler          ...   14          1   10          1    3
# 201188    Marc Gasol               ...   24          1   16          1    6
# 201583    Ryan Anderson            ...    9          1    8          1    2
# 201584    Courtney Lee             ...   10          1    7          1    4
# 201588    George Hill              ...   21          1    7          1    5
# 201599    DeAndre Jordan           ...   18          1   19          1    3
# 201961    Wayne Ellington          ...   21          1    7          1    6
# 202066    Garrett Temple           ...   19          1    9          1    4
# 202083    Wesley Matthews          ...   24          1    8          1    4
# 202325    Wesley Johnson           ...   10          1    8          1    3
# 202328    Greg Monroe              ...   17          1   10          1    3
# 202340    Avery Bradley            ...   21          1    9          1    4
# 202391    Jeremy Lin               ...   21          1    8          1    4
# 202683    Enes Kanter              ...   23          1   18          1    4
# 202685    Jonas Valanciunas        ...   24          1   17          1    3
# 202688    Brandon Knight           ...   16          1    6          1    4
# 202692    Alec Burks               ...   21          1   11          1    4
# 202693    Markieff Morris          ...   20          1   12          1    4
# 202697    Iman Shumpert            ...   20          1    9          1    5
# 202699    Tobias Harris            ...   29          1   11          1    5
# 202702    Kenneth Faried           ...   18          1   13          1    4
# 202703    Nikola Mirotic           ...   26          1   14          1    4
# 202710    Jimmy Butler             ...   28          1   12          1    7
# ...                                ...  ...        ...  ...        ...  ...
# 204025    Tim Frazier              ...   14          1   10          1    3
# 1626150   Andrew Harrison          ...    8          1    5          1    3
# 1626153   Delon Wright             ...   20          1   13          1    6
# 1626155   Sam Dekker               ...   16          1   10          1    4
# 1626162   Kelly Oubre Jr.          ...   28          1   13          1    6
# 1626166   Cameron Payne            ...   17          1    7          1    4
# 1626169   Stanley Johnson          ...   20          1   10          1    4
# 1626171   Bobby Portis             ...   22          1   13          1    5
# 1626174   Christian Wood           ...   15          1    8          1    3
# 1626246   Boban Marjanovic         ...   15          1   13          1    3
# 1627737   Marquese Chriss          ...   14          1   10          1    3
# 1627740   Henry Ellenson           ...   10          1    9          1    3
# 1627746   Skal Labissiere          ...    7          1    7          1    3
# 1627748   Thon Maker               ...   15          1   10          1    3
# 1627758   Ron Baker                ...    4          1    4          1    2
# 1627775   Patrick McCaw            ...    8          1    6          1    4
# 1627782   Wayne Selden             ...   18          1    9          1    5
# 1627789   Timothe Luwawu-Cabarrot  ...   16          1    9          1    3
# 1627826   Ivica Zubac              ...   20          1   15          1    4
# 1628249   Mitchell Creek           ...    4          1    3          1    2
# 1628372   Dennis Smith Jr.         ...   21          1   10          1    5
# 1628382   Justin Jackson           ...   23          1    8          1    3
# 1628393   Jawun Evans              ...    3          1    5          1    3
# 1628403   Caleb Swanigan           ...    5          1    9          1    3
# 1628416   Tyler Dorsey             ...   19          1    9          1    3
# 1629004   Svi Mykhailiuk           ...   11          1    6          1    3
# 1629013   Landry Shamet            ...   21          1    7          1    4
# 1629034   Ray Spalding             ...    7          1    8          1    4
# 1629150   Emanuel Terry            ...    3          1    2          1    3
# 1629168   BJ Johnson               ...    4          1    4          1    2
#
#                                    TEAM_ABBREVIATION  TEAM_ID_y  TOV  \
# PERSON_ID DISPLAY_FIRST_LAST
# 2199      Tyson Chandler                           2          2    5
# 2200      Pau Gasol                                2          2    3
# 2594      Kyle Korver                              2          2    4
# 2772      Trevor Ariza                             2          2    6
# 101139    CJ Miles                                 2          2    3
# 201147    Corey Brewer                             2          2    4
# 201160    Jason Smith                              3          3    3
# 201163    Wilson Chandler                          2          2    4
# 201188    Marc Gasol                               2          2    8
# 201583    Ryan Anderson                            2          2    3
# 201584    Courtney Lee                             2          2    3
# 201588    George Hill                              2          2    5
# 201599    DeAndre Jordan                           2          2    7
# 201961    Wayne Ellington                          2          2    5
# 202066    Garrett Temple                           2          2    5
# 202083    Wesley Matthews                          3          3    5
# 202325    Wesley Johnson                           2          2    4
# 202328    Greg Monroe                              3          3    4
# 202340    Avery Bradley                            2          2    5
# 202391    Jeremy Lin                               2          2    6
# 202683    Enes Kanter                              2          2    7
# 202685    Jonas Valanciunas                        2          2    6
# 202688    Brandon Knight                           2          2    4
# 202692    Alec Burks                               3          3    5
# 202693    Markieff Morris                          2          2    6
# 202697    Iman Shumpert                            2          2    5
# 202699    Tobias Harris                            2          2    8
# 202702    Kenneth Faried                           2          2    4
# 202703    Nikola Mirotic                           2          2    5
# 202710    Jimmy Butler                             2          2    5
# ...                                              ...        ...  ...
# 204025    Tim Frazier                              2          2    6
# 1626150   Andrew Harrison                          3          3    3
# 1626153   Delon Wright                             2          2    5
# 1626155   Sam Dekker                               2          2    4
# 1626162   Kelly Oubre Jr.                          2          2    6
# 1626166   Cameron Payne                            2          2    5
# 1626169   Stanley Johnson                          2          2    6
# 1626171   Bobby Portis                             2          2    6
# 1626174   Christian Wood                           2          2    5
# 1626246   Boban Marjanovic                         2          2    5
# 1627737   Marquese Chriss                          2          2    6
# 1627740   Henry Ellenson                           2          2    3
# 1627746   Skal Labissiere                          2          2    3
# 1627748   Thon Maker                               2          2    4
# 1627758   Ron Baker                                2          2    3
# 1627775   Patrick McCaw                            2          2    4
# 1627782   Wayne Selden                             2          2    5
# 1627789   Timothe Luwawu-Cabarrot                  2          2    4
# 1627826   Ivica Zubac                              2          2    6
# 1628249   Mitchell Creek                           2          2    2
# 1628372   Dennis Smith Jr.                         2          2    7
# 1628382   Justin Jackson                           2          2    3
# 1628393   Jawun Evans                              2          2    3
# 1628403   Caleb Swanigan                           2          2    4
# 1628416   Tyler Dorsey                             2          2    4
# 1629004   Svi Mykhailiuk                           2          2    4
# 1629013   Landry Shamet                            2          2    4
# 1629034   Ray Spalding                             2          2    3
# 1629150   Emanuel Terry                            2          2    2
# 1629168   BJ Johnson                               2          2    2
#
#                                    VIDEO_AVAILABLE  WL
# PERSON_ID DISPLAY_FIRST_LAST
# 2199      Tyson Chandler                         1   2
# 2200      Pau Gasol                              1   2
# 2594      Kyle Korver                            1   2
# 2772      Trevor Ariza                           1   2
# 101139    CJ Miles                               1   2
# 201147    Corey Brewer                           1   2
# 201160    Jason Smith                            2   2
# 201163    Wilson Chandler                        2   2
# 201188    Marc Gasol                             2   2
# 201583    Ryan Anderson                          1   2
# 201584    Courtney Lee                           1   2
# 201588    George Hill                            2   2
# 201599    DeAndre Jordan                         2   2
# 201961    Wayne Ellington                        2   2
# 202066    Garrett Temple                         2   2
# 202083    Wesley Matthews                        1   2
# 202325    Wesley Johnson                         1   2
# 202328    Greg Monroe                            1   2
# 202340    Avery Bradley                          2   2
# 202391    Jeremy Lin                             2   2
# 202683    Enes Kanter                            2   2
# 202685    Jonas Valanciunas                      1   2
# 202688    Brandon Knight                         1   2
# 202692    Alec Burks                             1   2
# 202693    Markieff Morris                        1   2
# 202697    Iman Shumpert                          2   2
# 202699    Tobias Harris                          2   2
# 202702    Kenneth Faried                         2   2
# 202703    Nikola Mirotic                         2   2
# 202710    Jimmy Butler                           2   2
# ...                                            ...  ..
# 204025    Tim Frazier                            1   2
# 1626150   Andrew Harrison                        1   2
# 1626153   Delon Wright                           1   2
# 1626155   Sam Dekker                             1   2
# 1626162   Kelly Oubre Jr.                        2   2
# 1626166   Cameron Payne                          1   2
# 1626169   Stanley Johnson                        1   2
# 1626171   Bobby Portis                           1   2
# 1626174   Christian Wood                         1   2
# 1626246   Boban Marjanovic                       2   2
# 1627737   Marquese Chriss                        1   2
# 1627740   Henry Ellenson                         2   2
# 1627746   Skal Labissiere                        1   2
# 1627748   Thon Maker                             2   2
# 1627758   Ron Baker                              1   2
# 1627775   Patrick McCaw                          2   2
# 1627782   Wayne Selden                           2   2
# 1627789   Timothe Luwawu-Cabarrot                2   2
# 1627826   Ivica Zubac                            2   2
# 1628249   Mitchell Creek                         1   2
# 1628372   Dennis Smith Jr.                       1   2
# 1628382   Justin Jackson                         2   2
# 1628393   Jawun Evans                            1   2
# 1628403   Caleb Swanigan                         1   2
# 1628416   Tyler Dorsey                           1   2
# 1629004   Svi Mykhailiuk                         1   2
# 1629013   Landry Shamet                          2   2
# 1629034   Ray Spalding                           1   2
# 1629150   Emanuel Terry                          1   1
# 1629168   BJ Johnson                             1   2
#
# [86 rows x 32 columns]

# %% [markdown]
# ## 7:
#
# Find the player who scored the least amount of points while playing in at least 40 games last season.

# %%
played_geq40 = df.groupby(["DISPLAY_FIRST_LAST",'PERSON_ID']).sum()[(df.groupby(["DISPLAY_FIRST_LAST",'PERSON_ID'])['PERSON_ID'].count() >= 40)]
min_pts = played_geq40['PTS'].idxmin()
# player = played_geq40[(played_geq40['PTS'] == min_pts)]
# player['MIN']
min_pts
# Out:
# ('Sindarius Thornwell', 1628414)

# %% [markdown]
# # Part 4: Pandas and Probability

# %% [markdown]
# ## 8:
#
# What is the probability that a random player had a game where they scored more than 40 points?

# %%
# total game rows with points > 40 / total game rows
more_than_40 = len(df[(df['PTS'] > 40)])
total_game_rows = len(df)
more_than_40/total_game_rows
# Out:
# 0.004214397915788667

# %% [markdown]
# ## 9:
#
# What is the probability that a randomly selected player from last season would average more than 20 points per game?

# %%
# total num of players with average > 20 / total number of players
geq_20pt_avg = len(df.groupby("PERSON_ID")['PTS'].mean()[(df.groupby("PERSON_ID")['PTS'].mean() > 20)])
total_players = len(df.groupby("PERSON_ID"))
geq_20pt_avg/total_players
# Out:
# 0.062264150943396226

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ## 10:
# Find the player who scored the least amount of points while playing in at least 40 games and averageing at least 15 minutes per game last season.

# %%
min_g15_and_40plus_games = df.groupby(['DISPLAY_FIRST_LAST']).sum()[(df.groupby(['DISPLAY_FIRST_LAST'])['MIN'].mean() > 15) & (df.groupby('DISPLAY_FIRST_LAST')['PERSON_ID'].count()>40)]

min_g15_and_40plus_games.idxmin()['PTS']
# Out:
# 'Tyson Chandler'

# %% [markdown]
# ## 11:
# Which player scored the largest share of points for their team throughout the season.

# %%
df1 = df.groupby(['DISPLAY_FIRST_LAST','TEAM_ABBREVIATION'])[['PTS']].sum()
df2 = df.groupby(['TEAM_ABBREVIATION'])[['PTS']].sum()
                                                
df3 = df1.join(df2, lsuffix='_player', rsuffix='_team')

df3['ratio'] = df3.apply(lambda x: x.PTS_player/x.PTS_team, axis=1)
df3.sort_values(by="ratio", ascending=False)
# Out:
#                                          PTS_player  PTS_team     ratio
# DISPLAY_FIRST_LAST    TEAM_ABBREVIATION
# James Harden          HOU                      2818      9341  0.301681
# Kemba Walker          CHA                      2102      9081  0.231472
# Paul George           OKC                      2159      9387  0.229999
# Bradley Beal          WAS                      2099      9350  0.224492
# Damian Lillard        POR                      2067      9402  0.219847
# Kevin Durant          GSW                      2027      9650  0.210052
# Blake Griffin         DET                      1841      8778  0.209729
# Giannis Antetokounmpo MIL                      1994      9686  0.205864
# Karl-Anthony Towns    MIN                      1880      9223  0.203838
# Donovan Mitchell      UTA                      1829      9161  0.199651
# Stephen Curry         GSW                      1881      9650  0.194922
# Devin Booker          PHX                      1700      8815  0.192853
# Nikola Vucevic        ORL                      1665      8800  0.189205
# LaMarcus Aldridge     SAS                      1727      9156  0.188619
# Joel Embiid           PHI                      1761      9445  0.186448
# D'Angelo Russell      BKN                      1712      9204  0.186006
# Buddy Hield           SAC                      1695      9363  0.181032
# DeMar DeRozan         SAS                      1635      9156  0.178571
# Russell Westbrook     OKC                      1675      9387  0.178438
# Nikola Jokic          DEN                      1604      9075  0.176749
# Klay Thompson         GSW                      1680      9650  0.174093
# Mike Conley           MEM                      1478      8490  0.174087
# Zach LaVine           CHI                      1492      8605  0.173388
# Kyrie Irving          BOS                      1596      9216  0.173177
# Luka Doncic           DAL                      1526      8927  0.170942
# Kawhi Leonard         TOR                      1596      9384  0.170077
# Trae Young            ATL                      1549      9294  0.166667
# Julius Randle         NOP                      1565      9466  0.165329
# LeBron James          LAL                      1505      9165  0.164212
# Bojan Bogdanovic      IND                      1454      8857  0.164164
# ...                                             ...       ...       ...
# Tahjere McCall        BKN                         4      9204  0.000435
# Pau Gasol             MIL                         4      9686  0.000413
# Jordan Sibert         ATL                         3      9294  0.000323
# Vincent Edwards       HOU                         3      9341  0.000321
# Angel Delgado         LAC                         3      9442  0.000318
# Andrew Harrison       MEM                         2      8490  0.000236
# DJ Stephens           MEM                         2      8490  0.000236
# Yante Maten           MIA                         2      8668  0.000231
# Kalin Lucas           DET                         2      8778  0.000228
# Kostas Antetokounmpo  DAL                         2      8927  0.000224
# Joe Chealey           CHA                         2      9081  0.000220
# Zhou Qi               HOU                         2      9341  0.000214
# Terrence Jones        HOU                         2      9341  0.000214
# BJ Johnson            SAC                         2      9363  0.000214
# Emanuel Terry         MIA                         1      8668  0.000115
# Okaro White           WAS                         0      9350  0.000000
# Ray Spalding          DAL                         0      8927  0.000000
# Zach Lofton           DET                         0      8778  0.000000
# Ron Baker             WAS                         0      9350  0.000000
# Donte Grantham        OKC                         0      9387  0.000000
# Kobi Simmons          CLE                         0      8567  0.000000
# Ike Anigbogu          IND                         0      8857  0.000000
# Tyler Zeller          ATL                         0      9294  0.000000
# George King           PHX                         0      8815  0.000000
# John Holland          CLE                         0      8567  0.000000
# Andre Ingram          LAL                         0      9165  0.000000
# Tyler Davis           OKC                         0      9387  0.000000
# Jawun Evans           OKC                         0      9387  0.000000
# Tyler Ulis            CHI                         0      8605  0.000000
# Eric Moreland         PHX                         0      8815  0.000000
#
# [622 rows x 3 columns]

# %% [markdown]
# ## 12:
#
# What is the probability that a randomly selected player had at least one game in which they scored 40 points last season.

# %%
# (num of players that have scored 40 at least once -- careful not to double count)/# players

num_players = len(df.groupby("DISPLAY_FIRST_LAST"))

player_scored_40 = df[(df['PTS'] == 40)]['DISPLAY_FIRST_LAST'].nunique()

player_scored_40/num_players
# Out:
# 0.035849056603773584

# %% [markdown]
# ## 13:
#
# A double-double is when a player records double-digits (10 or more) for any of the two follow categories: points, rebounds, assists, steals, or blocks.
# What is the probability that a randomly selected player had a double-double in a game last season?

# %%
player_agg_stats = df[(df['PTS'] >= 10) | (df['REB'] >= 10) | (df['AST'] >= 10) | (df['BLK'] >= 10) | (df['STL'] >= 10)]
players_stats_doubles = [] #list of lists -- one for each game for each player

player_agg_stats

# get the status of whether a player's stat is a double
for i in range(len(player_agg_stats)):
    stats = ['PTS', 'REB', 'AST', 'STL', 'BLK']
    
    
    player_stat_doubles = [] #list of bools, true if the stat is a double
    
    player_stat_doubles.append(player_agg_stats.iloc[i]["DISPLAY_FIRST_LAST"])
    
    for stat in stats:
        player_stat_doubles.append(player_agg_stats.iloc[i][stat] >= 10)
    
    players_stats_doubles.append(player_stat_doubles)

# %%
players_stats_doubles
# Out:
# [['Alex Abrines', True, False, False, False, False],
#  ['Alex Abrines', True, False, False, False, False],
#  ['Alex Abrines', True, False, False, False, False],
#  ['Quincy Acy', False, True, False, False, False],
#  ['Jaylen Adams', True, False, False, False, False],
#  ['Steven Adams', False, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', False, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', False, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', False, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', False, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', False, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, False, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Steven Adams', True, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', False, True, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', False, True, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', False, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', False, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', False, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', False, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, True, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['Bam Adebayo', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', False, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', False, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', False, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['LaMarcus Aldridge', True, False, False, False, False],
#  ['LaMarcus Aldridge', True, True, False, False, False],
#  ['Rawle Alkins', True, False, False, False, False],
#  ['Grayson Allen', True, False, False, False, False],
#  ['Grayson Allen', True, False, False, False, False],
#  ['Grayson Allen', True, False, False, False, False],
#  ['Grayson Allen', True, False, False, False, False],
#  ['Grayson Allen', True, False, False, False, False],
#  ['Jarrett Allen', False, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', False, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', False, True, False, False, False],
#  ['Jarrett Allen', False, True, False, False, False],
#  ['Jarrett Allen', False, True, False, False, False],
#  ['Jarrett Allen', False, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', False, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', False, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, False, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Jarrett Allen', True, True, False, False, False],
#  ['Kadeem Allen', True, False, False, False, False],
#  ['Kadeem Allen', True, False, False, False, False],
#  ['Kadeem Allen', True, False, False, False, False],
#  ['Kadeem Allen', True, False, False, False, False],
#  ['Kadeem Allen', True, False, False, False, False],
#  ['Kadeem Allen', True, False, False, False, False],
#  ['Kadeem Allen', True, False, False, False, False],
#  ['Kadeem Allen', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', False, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', False, True, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', False, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', False, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Al-Farouq Aminu', False, True, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', False, True, False, False, False],
#  ['Al-Farouq Aminu', True, True, False, False, False],
#  ['Al-Farouq Aminu', True, False, False, False, False],
#  ['Justin Anderson', True, False, False, False, False],
#  ['Justin Anderson', True, True, False, False, False],
#  ['Justin Anderson', True, False, False, False, False],
#  ['Justin Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, True, True, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', False, True, False, False, False],
#  ['Kyle Anderson', True, True, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', False, True, False, False, False],
#  ['Kyle Anderson', False, True, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', True, False, False, False, False],
#  ['Kyle Anderson', False, True, False, False, False],
#  ['Ryan Anderson', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, True, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, False, True, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, True, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, True, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, True, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', False, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, True, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, False, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, True, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Giannis Antetokounmpo', True, True, False, False, False],
#  ['Carmelo Anthony', True, False, False, False, False],
#  ['Carmelo Anthony', True, False, False, False, False],
#  ['Carmelo Anthony', True, False, False, False, False],
#  ['Carmelo Anthony', True, False, False, False, False],
#  ['Carmelo Anthony', False, True, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['OG Anunoby', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', False, False, True, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Ryan Arcidiacono', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, True, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, True, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, True, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, True, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, True, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['Trevor Ariza', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, True, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, True, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, True, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['D.J. Augustin', True, False, True, False, False],
#  ['D.J. Augustin', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', False, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, False, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Deandre Ayton', True, True, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Dwayne Bacon', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, True, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Marvin Bagley III', True, False, False, False, False],
#  ['Lonzo Ball', False, False, True, False, False],
#  ['Lonzo Ball', True, False, True, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', False, False, True, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, True, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, True, True, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, True, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', False, True, False, False, False],
#  ['Lonzo Ball', False, True, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', False, False, True, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Lonzo Ball', True, False, False, False, False],
#  ['Mo Bamba', False, True, False, False, False],
#  ['Mo Bamba', True, False, False, False, False],
#  ['Mo Bamba', False, True, False, False, False],
#  ['Mo Bamba', True, False, False, False, False],
#  ['Mo Bamba', True, False, False, False, False],
#  ['Mo Bamba', True, False, False, False, False],
#  ['Mo Bamba', True, False, False, False, False],
#  ['Mo Bamba', True, True, False, False, False],
#  ['Mo Bamba', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', False, False, True, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, True, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, False, False, False],
#  ['J.J. Barea', True, False, True, False, False],
#  ['J.J. Barea', True, False, True, False, False],
#  ['J.J. Barea', False, False, True, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, True, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, True, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, True, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, True, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Harrison Barnes', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, True, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Will Barton', True, False, False, False, False],
#  ['Keita Bates-Diop', True, False, False, False, False],
#  ['Keita Bates-Diop', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', False, True, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', False, True, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Nicolas Batum', True, False, False, False, False],
#  ['Jerryd Bayless', True, False, False, False, False],
#  ['Jerryd Bayless', True, False, False, False, False],
#  ['Jerryd Bayless', True, False, False, False, False],
#  ['Jerryd Bayless', True, False, True, False, False],
#  ['Jerryd Bayless', True, False, True, False, False],
#  ['Jerryd Bayless', True, False, False, False, False],
#  ['Jerryd Bayless', True, False, False, False, False],
#  ['Jerryd Bayless', True, False, False, False, False],
#  ['Jerryd Bayless', True, False, False, False, False],
#  ['Aron Baynes', True, True, False, False, False],
#  ['Aron Baynes', True, True, False, False, False],
#  ['Aron Baynes', False, True, False, False, False],
#  ['Aron Baynes', True, True, False, False, False],
#  ['Aron Baynes', True, False, False, False, False],
#  ['Aron Baynes', False, True, False, False, False],
#  ['Aron Baynes', True, False, False, False, False],
#  ['Aron Baynes', True, False, False, False, False],
#  ['Aron Baynes', True, False, False, False, False],
#  ['Aron Baynes', False, True, False, False, False],
#  ['Aron Baynes', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Kent Bazemore', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, True, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, True, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, True, False, False],
#  ['Bradley Beal', True, False, True, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, True, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, True, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, True, True, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, True, True, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, True, False, False, False],
#  ['Bradley Beal', True, True, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, True, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ['Bradley Beal', True, False, False, False, False],
#  ...]

# %%
num_triples = 0
num_doubles = 0
num_none = 0
    
players_with_doubles = []
players_with_triples = []

# count all of the doubles for each player, determine if they have 
# a double double or a triple double
for player in players_stats_doubles:
    if sum(player[1:-1]) >= 3 and (player[0] not in players_with_triples):
        players_with_triples.append(player[0])
        players_with_doubles.append(player[0])
        num_triples += 1
        num_doubles +=1
    elif sum(player[1:-1]) == 2 and (player[0] not in players_with_doubles):
        players_with_doubles.append(player[0])
        num_doubles += 1
    else:
        num_none += 1
    
num_doubles/530
# Out:
# 0.5433962264150943

# %% [markdown]
# ## 14:
#
# What is the probability that a randomnly selected game had a player record a triple-double (10+ counts in 3 categories) in that game?

# %%
# be careful not to double count double-doubles and triple-doubles!

# %% [markdown]
# # Part 5: Super Duper Challenge

# %% [markdown]
# ## 15:
#
# How many players last season averaged more points per game than their career average?
