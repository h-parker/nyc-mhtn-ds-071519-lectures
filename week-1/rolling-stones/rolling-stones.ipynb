# %% [markdown]
# # Instructions:

# %% [markdown]
# ## Getting Started
# In this exercise, we will be using data from `rolling stone's top 500 albums`. We have this data contained in the `data.csv` file. We will be building out the following functions to answer questions and interact with this data.
#
# > **remember:** reading from a csv file in python looks like the following:
#
# ```python
# import csv
#
#     with open(file_name) as f:
#         # we are using DictReader because we want our information to be in dictionary format.
#         reader = csv.DictReader(f)
#         # some more code
# ```
#
# Once we have our `reader` reading our file as dictionaries, we want our data to be a list of dictionaries. So, we need to loop through our `reader` and create a list. *hint: list comprehension / for loops are your friend"
#
# ```python
# # our data will look something like this once we have read it and turned it into a list of `OrderedDict`s
# # don't worry, the ordered dicts look different but we can interact with them the same way we do normal dicts
# [OrderedDict([('number', '1'), ('year', '1967'), ('album', "Sgt. Pepper's Lonely Hearts Club Band"), ('artist', 'The Beatles'), ('genre', 'Rock'), ('subgenre', 'Rock & Roll, Psychedelic Rock')]), OrderedDict([('number', '2'), ('year', '1966'), ('album', 'Pet Sounds'), ('artist', 'The Beach Boys'), ('genre', 'Rock'), ('subgenre', 'Pop Rock, Psychedelic Rock')]), OrderedDict([('number', '3'), ('year', '1966'), ('album', 'Revolver'), ('artist', 'The Beatles'), ('genre', 'Rock'), ('subgenre', 'Psychedelic Rock, Pop Rock')])]
# ```
#
# After we have our data formated the way we want it, we can now begin working on defining our functions.

# %% [markdown]
# ### Functions to build-out:
#
# * **Searching functions**
#   * Find by name - Takes in a string that represents the name of an album. Should return a dictionary with the correct album, or return `None`.
#   * Find by rank - Takes in a number that represents the rank in the list of top albums and returns the album with that rank. If there is no album with that rank, it returns `None`.
#   * Find by year - Takes in a number for the year in which an album was released and returns a list of albums that were released in that year. If there are no albums released in the given year, it returns an empty list.
#   * Find by years - Takes in a start year and end year. Returns a list of all albums that were released on or between the start and end years. If no albums are found for those years, then an empty list is returned.
#   * Find by ranks - Takes in a start rank and end rank. Returns a list of albums that are ranked between the start and end ranks. If no albums are found for those ranks, then an empty list is returned.
# * **All functions**
#   * All titles - Returns a list of titles for each album.
#   * All artists - Returns a list of artist names for each album.
# * **Questions to answer / functions**
#   * Artists with the most albums - Returns the artist with the highest amount of albums on the list of top albums
#   * Most popular word - Returns the word used most in amongst all album titles
#   * Histogram of albums by decade - Returns a histogram with each decade pointing to the number of albums released during that decade.
#   * Histogram by genre - Returns a histogram with each genre pointing to the number of albums that are categorized as being in that genre.

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Now that we have our functions querying our Album data, let's compare that data with the top 500 songs. We have another file -- a text file! -- that contains the data we need for the top 500 songs. Reading a text file is pretty similar to reading a csv file, however, it tends to need a bit more massaging to get your data formatted the way you want it.
#
# ```python
#     # open the text file in read
#     text_file = open('top-500-songs.txt', 'r')
#     # read each line of the text file
#     # here is where you can print out the lines to your terminal and get an idea
#     # for how you might think about re-formatting the data
#     lines = text_file.readlines()
#
#     print(lines)
#     # the output will look something like this:
# ['1\tLike a Rolling Stone\tBob Dylan\t1965\n', '2\tSatisfaction\tThe Rolling Stones\t1965\n', '3\tImagine\tJohn Lennon\t1971\n', "4\tWhat's Going On\tMarvin Gaye\t1971\n", '5\tRespect\tAretha Franklin\t1967\n', '6\tGood Vibrations\tThe Beach Boys\t1966\n', '7\tJohnny B. Goode\tChuck Berry\t1958\n', '8\tHey Jude\tThe Beatles\t1968\n', ...]
# ```
#
# It looks like `\t` is how the text file is separating each element on a line. So, we need a function that can separate a string into a list. Then we can tell this function on what to split our string (i.e. `\t`). From there we will have a list of lists that are formatted like the following:
# ```python
# ["RANK", "NAME", "ARTIST", "YEAR"]
# ```
# We need to use our knowledge of iterating to go through each of these elements and turn them into dictionaries with the keys, "rank", "name", "artist", "year", pointing to the appropriate values. So, for song number 1, we want it to look like:
# ```python
# {'rank': 1, 'name': "Like a Rolling Stone", 'artist'"Bob Dylan": , 'year': 1965}
# ```
#
# Once we have a list of songs that are formatted like the above, we can move on to figuring out which songs are from the top albums and which albums and artists have the most 'top songs'.

# %% [markdown]
# ### Working with the top 500 songs

# %% [markdown]
# If we can't already re-use our searching functions (i.e. Find by name, Find by rank, Find by year, Find by years, Find by ranks), all functions (i.e. all titles, all artists), and questions-to-answer functions (i.e. Artists with the most albums (or songs), Most popular word, Histogram by decade, Histogram by genre) with the song data we just formatted, then refactor these functions so that they can be used with either set of data. This is a good practice for ensuring that our code is as reusable and modular as possible, which is important when writing code for any project, especially when it comes time to scale a project. Things are easier to read, and there is less code to worry about (and more importantly there is less code to debug when something goes wrong).
#
# Once we have our functions working for both sets of data, we can start writing new functions!
#
# Luckily for us, this next dataset is already made for us. We were curious to find out which songs on the top 500 songs overlapped with the top albums and vice versa. So, we created a data set that is a list of dictionaries in JSON format. Each dictionary contains the name of the artist, the album, and the tracks (songs) on that given album. We can use this data to check which songs on the top 500 list are featured on the albums on the top albums list.
#
# To load our JSON file we will write:
#
# ```python
# import json
#
# file = open('track_data.json', 'r')
# json_data = json.load(file)
#
# print(json_data)
# # output will look like this:
# [{'artist': 'The Beatles', 'album': "Sgt. Pepper's Lonely Hearts Club Band", 'tracks': ["Sgt. Pepper's Lonely Hearts Club Band - Remix", 'With A Little Help From My Friends - Remix', 'Lucy In The Sky With Diamonds - Remix', 'Getting Better - Remix', 'Fixing A Hole - Remix', "She's Leaving Home - Remix", 'Being For The Benefit Of Mr. Kite! - Remix', 'Within You Without You - Remix', "When I'm Sixty-Four - Remix", 'Lovely Rita - Remix', 'Good Morning Good Morning - Remix', "Sgt. Pepper's Lonely Hearts Club Band (Reprise) - Remix", 'A Day In The Life - Remix', "Sgt. Pepper's Lonely Hearts Club Band - Take 9 And Speech", 'With A Little Help From My Friends - Take 1 / False Start And Take 2 / Instrumental', 'Lucy In The Sky With Diamonds - Take 1', 'Getting Better - Take 1 / Instrumental And Speech At The End', 'Fixing A Hole - Speech And Take 3', "She's Leaving Home - Take 1 / Instrumental", 'Being For The Benefit Of Mr. Kite! - Take 4', 'Within You Without You - Take 1 / Indian Instruments', "When I'm Sixty-Four - Take 2", 'Lovely Rita - Speech And Take 9', 'Good Morning Good Morning - Take 8', "Sgt. Pepper's Lonely Hearts Club Band (Reprise) - Speech And Take 8", 'A Day In The Life - Take 1 With Hums', 'Strawberry Fields Forever - Take 7', 'Strawberry Fields Forever - Take 26', 'Strawberry Fields Forever - Stereo Mix 2015', 'Penny Lane - Take 6 / Instrumental', 'Penny Lane - Stereo Mix 2017']}, {'artist': 'The Beach Boys', 'album': 'Pet Sounds', 'tracks': ["Wouldn't It Be Nice - Digitally Remastered 96", 'You Still Believe In Me - Digitally Remastered 96', "That's Not Me - 1996 Digital Remaster", "Don't Talk (Put Your Head On My Shoulder) - 1996 Digital Remaster", "I'm Waiting For The Day - Digitally Remastered 96", "Let's Go Away For Awhile - Digitally Remastered 96", 'Sloop John B - 1996 - Remaster', 'God Only Knows - 1997 - Remaster', "I Know There's An Answer - Digitally Remastered 96", 'Here Today - Digitally Remastered 96', "I Just Wasn't Made For These Times - Digitally Remastered 96", 'Pet Sounds - Digitally Remastered 96', 'Caroline, No - 1996 Digital Remaster', 'Hang On To Your Ego', "Wouldn't It Be Nice - 2000 - Remaster", 'You Still Believe In Me - 1996 Digital Remaster', "That's Not Me - 1996 Digital Remaster", "Don't Talk (Put Your Head On My Shoulder) - 1996 Digital Remaster", "I'm Waiting For The Day - 1996 Digital Remaster", "Let's Go Away For Awhile - 1996 Digital Remaster", 'Sloop John B - 1996 Digital Remaster', 'God Only Knows - 1996 Digital Remaster', "I Know There's An Answer - 1996 Digital Remaster", 'Here Today - 1996 Digital Remaster', "I Just Wasn't Made For These Times - 1996 Digital Remaster", 'Pet Sounds - 1996 Digital Remaster', 'Caroline, No - 1996 Digital Remaster']}, {'artist': 'The Beatles', 'album': 'Revolver', 'tracks': ['Taxman - Remastered', 'Eleanor Rigby - Remastered', "I'm Only Sleeping - Remastered", 'Love You To - Remastered', 'Here, There And Everywhere - Remastered', 'Yellow Submarine - Remastered', 'She Said She Said - Remastered', 'Good Day Sunshine - Remastered', 'And Your Bird Can Sing - Remastered', 'For No One - Remastered', 'Doctor Robert - Remastered', 'I Want To Tell You - Remastered', 'Got To Get You Into My Life - Remastered', 'Tomorrow Never Knows - Remastered']}, {'artist': 'Bob Dylan', 'album': 'Highway 61 Revisited', 'tracks': ['Like a Rolling Stone', 'Tombstone Blues', 'It Takes a Lot to Laugh, It Takes a Train to Cry', 'From a Buick 6', 'Ballad of a Thin Man', 'Queen Jane Approximately', 'Highway 61 Revisited', "Just Like Tom Thumb's Blues", 'Desolation Row']}, ...]
# ```

# %% [markdown]
# ### Bonus: Define the following functions:
#
# **albumWithMostTopSongs** - returns the name of the artist and album that has that most songs featured on the top 500 songs list
#
# **albumsWithTopSongs** - returns a list with the name of only the albums that have tracks featured on the list of top 500 songs
#
# **songsThatAreOnTopAlbums** - returns a list with the name of only the songs featured on the list of top albums
#
# **top10AlbumsByTopSongs** - returns a histogram with the 10 albums that have the most songs that appear in the top songs list. The album names should point to the number of songs that appear on the top 500 songs list.
#
# **topOverallArtist** - Artist featured with the most songs and albums on the two lists. This means that if Brittany Spears had 3 of her albums featured on the top albums listed and 10 of her songs featured on the top songs, she would have a total of 13. The artist with the highest aggregate score would be the top overall artist.

# %%
import csv #number,year,album,artist,genre,subgenre
music = []
with open('data.csv') as f:
    reader = csv.DictReader(f)
    for row in reader:
        music.append({'number': row['number'], 
                      'album': row ['album'],
                      'year': row['year'], 
                      'artist': row['artist'], 
                      'genre': row['subgenre']
                      })
# Out:
# [{'number': '1',
#   'album': "Sgt. Pepper's Lonely Hearts Club Band",
#   'year': '1967',
#   'artist': 'The Beatles',
#   'genre': 'Rock & Roll, Psychedelic Rock'},
#  {'number': '2',
#   'album': 'Pet Sounds',
#   'year': '1966',
#   'artist': 'The Beach Boys',
#   'genre': 'Pop Rock, Psychedelic Rock'},
#  {'number': '3',
#   'album': 'Revolver',
#   'year': '1966',
#   'artist': 'The Beatles',
#   'genre': 'Psychedelic Rock, Pop Rock'},
#  {'number': '4',
#   'album': 'Highway 61 Revisited',
#   'year': '1965',
#   'artist': 'Bob Dylan',
#   'genre': 'Folk Rock, Blues Rock'},
#  {'number': '5',
#   'album': 'Rubber Soul',
#   'year': '1965',
#   'artist': 'The Beatles',
#   'genre': 'Pop Rock'},
#  {'number': '6',
#   'album': "What's Going On",
#   'year': '1971',
#   'artist': 'Marvin Gaye',
#   'genre': 'Soul'},
#  {'number': '7',
#   'album': 'Exile on Main St.',
#   'year': '1972',
#   'artist': 'The Rolling Stones',
#   'genre': 'Blues Rock, Rock & Roll, Classic Rock'},
#  {'number': '8',
#   'album': 'London Calling',
#   'year': '1979',
#   'artist': 'The Clash',
#   'genre': 'Punk, New Wave'},
#  {'number': '9',
#   'album': 'Blonde on Blonde',
#   'year': '1966',
#   'artist': 'Bob Dylan',
#   'genre': 'Folk Rock, Rhythm & Blues'},
#  {'number': '10',
#   'album': 'The Beatles ("The White Album")',
#   'year': '1968',
#   'artist': 'The Beatles',
#   'genre': 'Rock & Roll, Pop Rock, Psychedelic Rock, Experimental'},
#  {'number': '11',
#   'album': 'The Sun Sessions',
#   'year': '1976',
#   'artist': 'Elvis Presley',
#   'genre': 'Rock & Roll'},
#  {'number': '12',
#   'album': 'Kind of Blue',
#   'year': '1959',
#   'artist': 'Miles Davis',
#   'genre': 'Modal'},
#  {'number': '13',
#   'album': 'The Velvet Underground & Nico',
#   'year': '1967',
#   'artist': 'The Velvet Underground',
#   'genre': 'Garage Rock, Art Rock, Experimental'},
#  {'number': '14',
#   'album': 'Abbey Road',
#   'year': '1969',
#   'artist': 'The Beatles',
#   'genre': 'Psychedelic Rock, Classic Rock, Pop Rock'},
#  {'number': '15',
#   'album': 'Are You Experienced',
#   'year': '1967',
#   'artist': 'The Jimi Hendrix Experience',
#   'genre': 'Blues Rock, Psychedelic Rock'},
#  {'number': '16',
#   'album': 'Blood on the Tracks',
#   'year': '1975',
#   'artist': 'Bob Dylan',
#   'genre': 'Folk Rock, Acoustic, Ballad'},
#  {'number': '17',
#   'album': 'Nevermind',
#   'year': '1991',
#   'artist': 'Nirvana',
#   'genre': 'Alternative Rock, Grunge'},
#  {'number': '18',
#   'album': 'Born to Run',
#   'year': '1975',
#   'artist': 'Bruce Springsteen',
#   'genre': 'Pop Rock'},
#  {'number': '19',
#   'album': 'Astral Weeks',
#   'year': '1968',
#   'artist': 'Van Morrison',
#   'genre': 'Acoustic, Classic Rock, Free Improvisation'},
#  {'number': '20',
#   'album': 'Thriller',
#   'year': '1982',
#   'artist': 'Michael Jackson',
#   'genre': 'Disco'},
#  {'number': '21',
#   'album': 'The Great Twenty Eight',
#   'year': '1982',
#   'artist': 'Chuck Berry',
#   'genre': 'Rock & Roll'},
#  {'number': '22',
#   'album': 'The Complete Recordings',
#   'year': '1990',
#   'artist': 'Robert Johnson',
#   'genre': 'Delta Blues'},
#  {'number': '23',
#   'album': 'John Lennon/Plastic Ono Band',
#   'year': '1970',
#   'artist': 'John Lennon / Plastic Ono Band',
#   'genre': 'Pop Rock'},
#  {'number': '24',
#   'album': 'Innervisions',
#   'year': '1973',
#   'artist': 'Stevie Wonder',
#   'genre': 'Soul'},
#  {'number': '25',
#   'album': 'Live at the Apollo, 1962',
#   'year': '1963',
#   'artist': 'James Brown',
#   'genre': 'Rhythm & Blues, Soul'},
#  {'number': '26',
#   'album': 'Rumours',
#   'year': '1977',
#   'artist': 'Fleetwood Mac',
#   'genre': 'Pop Rock'},
#  {'number': '27',
#   'album': 'The Joshua Tree',
#   'year': '1987',
#   'artist': 'U2',
#   'genre': 'Alternative Rock, Pop Rock'},
#  {'number': '28',
#   'album': "Who's Next",
#   'year': '1971',
#   'artist': 'The Who',
#   'genre': 'Hard Rock, Mod, Prog Rock, Psychedelic Rock'},
#  {'number': '29',
#   'album': 'Led Zeppelin',
#   'year': '1969',
#   'artist': 'Led Zeppelin',
#   'genre': 'Blues Rock, Hard Rock'},
#  {'number': '30',
#   'album': 'Blue',
#   'year': '1971',
#   'artist': 'Joni Mitchell',
#   'genre': 'Acoustic, Ballad, Folk'},
#  {'number': '31',
#   'album': 'Bringing It All Back Home',
#   'year': '1965',
#   'artist': 'Bob Dylan',
#   'genre': 'Folk Rock, Folk'},
#  {'number': '32',
#   'album': 'Let It Bleed',
#   'year': '1969',
#   'artist': 'The Rolling Stones',
#   'genre': 'Blues Rock, Hard Rock'},
#  {'number': '33',
#   'album': 'Ramones',
#   'year': '1976',
#   'artist': 'Ramones',
#   'genre': 'Rock & Roll, Punk'},
#  {'number': '34',
#   'album': 'Music From Big Pink',
#   'year': '1968',
#   'artist': 'The Band',
#   'genre': 'Folk Rock, Acoustic, Blues Rock'},
#  {'number': '35',
#   'album': 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars',
#   'year': '1972',
#   'artist': 'David Bowie',
#   'genre': 'Classic Rock, Glam'},
#  {'number': '36',
#   'album': 'Tapestry',
#   'year': '1971',
#   'artist': 'Carole King',
#   'genre': 'Folk Rock, Soft Rock'},
#  {'number': '37',
#   'album': 'Hotel California',
#   'year': '1976',
#   'artist': 'Eagles',
#   'genre': 'Classic Rock'},
#  {'number': '38',
#   'album': 'The Anthology',
#   'year': '2001',
#   'artist': 'Muddy Waters',
#   'genre': 'Folk'},
#  {'number': '39',
#   'album': 'Please Please Me',
#   'year': '1963',
#   'artist': 'The Beatles',
#   'genre': 'Beat, Rock & Roll'},
#  {'number': '40',
#   'album': 'Forever Changes',
#   'year': '1967',
#   'artist': 'Love',
#   'genre': 'Folk Rock, Psychedelic Rock'},
#  {'number': '41',
#   'album': "Never Mind the Bollocks Here's the Sex Pistols",
#   'year': '1977',
#   'artist': 'Sex Pistols',
#   'genre': 'Punk'},
#  {'number': '42',
#   'album': 'The Doors',
#   'year': '1967',
#   'artist': 'The Doors',
#   'genre': 'Psychedelic Rock'},
#  {'number': '43',
#   'album': 'The Dark Side of the Moon',
#   'year': '1973',
#   'artist': 'Pink Floyd',
#   'genre': 'Prog Rock'},
#  {'number': '44',
#   'album': 'Horses',
#   'year': '1975',
#   'artist': 'Patti Smith',
#   'genre': 'Art Rock'},
#  {'number': '45',
#   'album': 'The Brown Album',
#   'year': '1969',
#   'artist': 'The Band',
#   'genre': 'Soundtrack, Modern Classical, Contemporary, Score'},
#  {'number': '46',
#   'album': 'The Best of Bob Marley and The Wailers',
#   'year': '1984',
#   'artist': 'Bob Marley & The Wailers',
#   'genre': 'Reggae, Roots Reggae'},
#  {'number': '47',
#   'album': 'A Love Supreme',
#   'year': '1965',
#   'artist': 'John Coltrane',
#   'genre': 'Free Jazz, Hard Bop, Modal'},
#  {'number': '48',
#   'album': 'It Takes a Nation of Millions to Hold Us Back',
#   'year': '1988',
#   'artist': 'Public Enemy',
#   'genre': 'Conscious'},
#  {'number': '49',
#   'album': 'At Fillmore East',
#   'year': '1971',
#   'artist': 'The Allman Brothers Band',
#   'genre': 'Blues Rock'},
#  {'number': '50',
#   'album': "Here's Little Richard",
#   'year': '1957',
#   'artist': 'Little Richard',
#   'genre': 'Rock & Roll, Rhythm & Blues'},
#  {'number': '51',
#   'album': 'Bridge Over Troubled Water',
#   'year': '1970',
#   'artist': 'Simon & Garfunkel',
#   'genre': 'Folk Rock, Classic Rock'},
#  {'number': '52',
#   'album': 'Greatest Hits',
#   'year': '1975',
#   'artist': 'Al Green',
#   'genre': 'Soul'},
#  {'number': '53',
#   'album': 'Meet The Beatles!',
#   'year': '1964',
#   'artist': 'The Beatles',
#   'genre': 'Beat, Rock & Roll'},
#  {'number': '54',
#   'album': 'The Birth of Soul',
#   'year': '1991',
#   'artist': 'Ray Charles',
#   'genre': 'Rhythm & Blues, Big Band, Soul, Soul-Jazz'},
#  {'number': '55',
#   'album': 'Electric Ladyland',
#   'year': '1968',
#   'artist': 'The Jimi Hendrix Experience',
#   'genre': 'Electric Blues, Psychedelic Rock'},
#  {'number': '56',
#   'album': 'Elvis Presley',
#   'year': '1956',
#   'artist': 'Elvis Presley',
#   'genre': 'Rock & Roll, Rockabilly'},
#  {'number': '57',
#   'album': 'Songs in the Key of Life',
#   'year': '1976',
#   'artist': 'Stevie Wonder',
#   'genre': 'Soul, Disco'},
#  {'number': '58',
#   'album': 'Beggars Banquet',
#   'year': '1968',
#   'artist': 'The Rolling Stones',
#   'genre': 'Blues Rock, Southern Rock, Classic Rock'},
#  {'number': '59',
#   'album': 'Chronicle: The 20 Greatest Hits',
#   'year': '1976',
#   'artist': 'Creedence Clearwater Revival',
#   'genre': 'None'},
#  {'number': '61',
#   'album': 'Greatest Hits',
#   'year': '1970',
#   'artist': 'Sly & The Family Stone',
#   'genre': 'Rhythm & Blues, Funk'},
#  {'number': '62',
#   'album': 'Appetite for Destruction',
#   'year': '1987',
#   'artist': "Guns N' Roses",
#   'genre': 'Hard Rock, Heavy Metal'},
#  {'number': '63',
#   'album': 'Achtung Baby',
#   'year': '1991',
#   'artist': 'U2',
#   'genre': 'Pop Rock, Synth-pop, Alternative Rock, Arena Rock'},
#  {'number': '64',
#   'album': 'Sticky Fingers',
#   'year': '1971',
#   'artist': 'The Rolling Stones',
#   'genre': 'Classic Rock'},
#  {'number': '65',
#   'album': 'Back to Mono',
#   'year': '1991',
#   'artist': 'Phil Spector',
#   'genre': 'Doo Wop, Pop Rock, Ballad, Rhythm & Blues'},
#  {'number': '66',
#   'album': 'Moondance',
#   'year': '1970',
#   'artist': 'Van Morrison',
#   'genre': 'Folk Rock, Rhythm & Blues, Classic Rock, Contemporary Jazz'},
#  {'number': '67',
#   'album': 'Kid A',
#   'year': '2000',
#   'artist': 'Radiohead',
#   'genre': 'Alternative Rock, IDM, Experimental'},
#  {'number': '68',
#   'album': 'Off the Wall',
#   'year': '1979',
#   'artist': 'Michael Jackson',
#   'genre': 'Disco, Soul, Ballad'},
#  {'number': '69',
#   'album': '[Led Zeppelin IV]',
#   'year': '1971',
#   'artist': 'Led Zeppelin',
#   'genre': 'Hard Rock, Classic Rock, Blues Rock'},
#  {'number': '70',
#   'album': 'The Stranger',
#   'year': '1977',
#   'artist': 'Billy Joel',
#   'genre': 'Pop Rock'},
#  {'number': '71',
#   'album': 'Graceland',
#   'year': '1986',
#   'artist': 'Paul Simon',
#   'genre': 'Folk Rock, Pop Rock, African, Afrobeat, Zydeco, Funk, Rhythm & Blues'},
#  {'number': '72',
#   'album': 'Superfly',
#   'year': '1972',
#   'artist': 'Curtis Mayfield',
#   'genre': 'Soundtrack, Soul'},
#  {'number': '73',
#   'album': 'Physical Graffiti',
#   'year': '1975',
#   'artist': 'Led Zeppelin',
#   'genre': 'Classic Rock'},
#  {'number': '74',
#   'album': 'After the Gold Rush',
#   'year': '1970',
#   'artist': 'Neil Young',
#   'genre': 'Rock & Roll, Country Rock'},
#  {'number': '75',
#   'album': 'Star Time',
#   'year': '1991',
#   'artist': 'James Brown',
#   'genre': 'Soul, Funk, Disco'},
#  {'number': '76',
#   'album': 'Purple Rain',
#   'year': '1984',
#   'artist': 'Prince and the Revolution',
#   'genre': 'Pop Rock, Funk, Soundtrack, Synth-pop'},
#  {'number': '77',
#   'album': 'Back in Black',
#   'year': '1980',
#   'artist': 'AC/DC',
#   'genre': 'Hard Rock'},
#  {'number': '78',
#   'album': 'Otis Blue: Otis Redding Sings Soul',
#   'year': '1965',
#   'artist': 'Otis Redding',
#   'genre': 'Soul'},
#  {'number': '79',
#   'album': 'Led Zeppelin II',
#   'year': '1969',
#   'artist': 'Led Zeppelin',
#   'genre': 'Blues Rock, Classic Rock, Hard Rock'},
#  {'number': '80',
#   'album': 'Imagine',
#   'year': '1971',
#   'artist': 'John Lennon',
#   'genre': 'Pop Rock'},
#  {'number': '81',
#   'album': 'The Clash',
#   'year': '1977',
#   'artist': 'The Clash',
#   'genre': 'Punk'},
#  {'number': '82',
#   'album': 'Harvest',
#   'year': '1972',
#   'artist': 'Neil Young',
#   'genre': 'Folk Rock, Country Rock, Classic Rock'},
#  {'number': '83',
#   'album': 'Axis: Bold as Love',
#   'year': '1967',
#   'artist': 'The Jimi Hendrix Experience',
#   'genre': 'Psychedelic Rock, Electric Blues'},
#  {'number': '84',
#   'album': 'I Never Loved a Man the Way I Love You',
#   'year': '1967',
#   'artist': 'Aretha Franklin',
#   'genre': 'Soul'},
#  {'number': '85',
#   'album': 'Lady Soul',
#   'year': '1968',
#   'artist': 'Aretha Franklin',
#   'genre': 'Soul'},
#  {'number': '86',
#   'album': 'Born in the U.S.A.',
#   'year': '1984',
#   'artist': 'Bruce Springsteen',
#   'genre': 'Pop Rock'},
#  {'number': '87',
#   'album': 'The Wall',
#   'year': '1979',
#   'artist': 'Pink Floyd',
#   'genre': 'Alternative Rock, Prog Rock'},
#  {'number': '88',
#   'album': 'At Folsom Prison',
#   'year': '1968',
#   'artist': 'Johnny Cash',
#   'genre': 'Country'},
#  {'number': '89',
#   'album': 'Dusty in Memphis',
#   'year': '1969',
#   'artist': 'Dusty Springfield',
#   'genre': 'Pop Rock, Soul'},
#  {'number': '90',
#   'album': 'Talking Book',
#   'year': '1972',
#   'artist': 'Stevie Wonder',
#   'genre': 'Soul, Funk'},
#  {'number': '91',
#   'album': 'Goodbye Yellow Brick Road',
#   'year': '1973',
#   'artist': 'Elton John',
#   'genre': 'Pop Rock, Classic Rock'},
#  {'number': '92',
#   'album': '20 Golden Greats',
#   'year': '1978',
#   'artist': 'Buddy Holly',
#   'genre': 'Rock & Roll'},
#  {'number': '93',
#   'album': "Sign 'O' the Times",
#   'year': '1987',
#   'artist': 'Prince',
#   'genre': 'Ska, Reggae-Pop'},
#  {'number': '94',
#   'album': '40 Greatest Hits',
#   'year': '1984',
#   'artist': 'Hank Williams',
#   'genre': 'Country'},
#  {'number': '95',
#   'album': 'Bitches Brew',
#   'year': '1970',
#   'artist': 'Miles Davis',
#   'genre': 'Fusion'},
#  {'number': '96',
#   'album': 'Tommy',
#   'year': '1969',
#   'artist': 'The Who',
#   'genre': 'Psychedelic Rock'},
#  {'number': '97',
#   'album': "The Freewheelin' Bob Dylan",
#   'year': '1963',
#   'artist': 'Bob Dylan',
#   'genre': 'Folk'},
#  {'number': '98',
#   'album': "This Year's Model",
#   'year': '1978',
#   'artist': 'Elvis Costello',
#   'genre': 'New Wave'},
#  {'number': '99',
#   'album': "There's a Riot Goin' On",
#   'year': '1971',
#   'artist': 'Sly & The Family Stone',
#   'genre': 'Rhythm & Blues, Funk'},
#  {'number': '100',
#   'album': 'Odessey and Oracle',
#   'year': '1968',
#   'artist': 'The Zombies',
#   'genre': 'Psychedelic Rock'},
#  {'number': '101',
#   'album': 'In the Wee Small Hours',
#   'year': '1955',
#   'artist': 'Frank Sinatra',
#   'genre': 'Big Band, Ballad'},
#  {'number': '102',
#   'album': 'Fresh Cream',
#   'year': '1966',
#   'artist': 'Cream',
#   'genre': 'Blues Rock, Electric Blues'},
#  {'number': '103',
#   'album': 'Giant Steps',
#   'year': '1959',
#   'artist': 'John Coltrane',
#   'genre': 'Hard Bop'},
#  {'number': '104',
#   'album': 'Sweet Baby James',
#   'year': '1970',
#   'artist': 'James Taylor',
#   'genre': 'Folk Rock, Acoustic, Soft Rock'},
#  {'number': '106',
#   'album': 'Rocket to Russia',
#   'year': '1977',
#   'artist': 'Ramones',
#   'genre': 'Rock & Roll, Punk'},
#  {'number': '107',
#   'album': 'Portrait of a Legend 1951-1964',
#   'year': '2003',
#   'artist': 'Sam Cooke',
#   'genre': 'Soul, Rhythm & Blues, Gospel, Cha-Cha'},
#  {'number': '108',
#   'album': 'Hunky Dory',
#   'year': '1971',
#   'artist': 'David Bowie',
#   'genre': 'Classic Rock, Glam'},
#  {'number': '109',
#   'album': 'Aftermath',
#   'year': '1966',
#   'artist': 'The Rolling Stones',
#   'genre': 'Blues Rock, Pop Rock'},
#  {'number': '110',
#   'album': 'Loaded',
#   'year': '1970',
#   'artist': 'The Velvet Underground',
#   'genre': 'Art Rock, Classic Rock'},
#  {'number': '111',
#   'album': 'The Bends',
#   'year': '1995',
#   'artist': 'Radiohead',
#   'genre': 'Alternative Rock'},
#  {'number': '112',
#   'album': 'If You Can Believe Your Eyes and Ears',
#   'year': '1966',
#   'artist': 'The Mamas and the Papas',
#   'genre': 'Folk Rock, Pop Rock'},
#  {'number': '113',
#   'album': 'Court and Spark',
#   'year': '1974',
#   'artist': 'Joni Mitchell',
#   'genre': 'Soft Rock, Pop Rock'},
#  {'number': '114',
#   'album': 'Disraeli Gears',
#   'year': '1967',
#   'artist': 'Cream',
#   'genre': 'Psychedelic Rock, Blues Rock'},
#  {'number': '115',
#   'album': 'The Who Sell Out',
#   'year': '1967',
#   'artist': 'The Who',
#   'genre': 'Psychedelic Rock, Mod'},
#  {'number': '116',
#   'album': 'Out of Our Heads',
#   'year': '1965',
#   'artist': 'The Rolling Stones',
#   'genre': 'Blues Rock, Rock & Roll'},
#  {'number': '117',
#   'album': 'Layla and Other Assorted Love Songs',
#   'year': '1970',
#   'artist': 'Derek and the Dominos',
#   'genre': 'Blues Rock'},
#  {'number': '118',
#   'album': 'Late Registration',
#   'year': '2005',
#   'artist': 'Kanye West',
#   'genre': 'None'},
#  {'number': '119',
#   'album': 'At Last!',
#   'year': '1960',
#   'artist': 'Etta James',
#   'genre': 'Rhythm & Blues, Soul'},
#  {'number': '120',
#   'album': 'Sweetheart of the Rodeo',
#   'year': '1968',
#   'artist': 'The Byrds',
#   'genre': 'Folk Rock, Country Rock'},
#  {'number': '121',
#   'album': 'Stand!',
#   'year': '1969',
#   'artist': 'Sly & The Family Stone',
#   'genre': 'Funk, Psychedelic, Disco'},
#  {'number': '122',
#   'album': 'The Harder They Come',
#   'year': '1972',
#   'artist': 'Various Artists',
#   'genre': 'Reggae,Roots Reggae,Rocksteady,Contemporary,Soundtrack'},
#  {'number': '123',
#   'album': 'Raising Hell',
#   'year': '1986',
#   'artist': 'Run D.M.C.',
#   'genre': 'None'},
#  {'number': '124',
#   'album': 'Moby Grape',
#   'year': '1967',
#   'artist': 'Moby Grape',
#   'genre': 'Folk Rock, Psychedelic Rock'},
#  {'number': '125',
#   'album': 'Pearl',
#   'year': '1971',
#   'artist': 'Janis Joplin',
#   'genre': 'Blues Rock'},
#  {'number': '126',
#   'album': 'Catch a Fire',
#   'year': '1973',
#   'artist': 'The Wailers',
#   'genre': 'Roots Reggae'},
#  {'number': '127',
#   'album': 'Younger Than Yesterday',
#   'year': '1967',
#   'artist': 'The Byrds',
#   'genre': 'Folk Rock, Psychedelic Rock'},
#  {'number': '128',
#   'album': 'Raw Power',
#   'year': '1973',
#   'artist': 'Iggy and The Stooges',
#   'genre': 'Garage Rock, Hard Rock, Punk'},
#  {'number': '129',
#   'album': 'Remain in Light',
#   'year': '1980',
#   'artist': 'Talking Heads',
#   'genre': 'New Wave, Art Rock, Funk'},
#  {'number': '130',
#   'album': 'Marquee Moon',
#   'year': '1977',
#   'artist': 'Television',
#   'genre': 'New Wave, Punk'},
#  {'number': '131',
#   'album': 'Paranoid',
#   'year': '1970',
#   'artist': 'Black Sabbath',
#   'genre': 'Hard Rock, Heavy Metal'},
#  {'number': '132',
#   'album': 'Saturday Night Fever: The Original Movie Soundtrack Deluxe Edition',
#   'year': '1977',
#   'artist': 'Various Artists',
#   'genre': 'Soundtrack,Disco'},
#  {'number': '133',
#   'album': 'The Wild, the Innocent & the E Street Shuffle',
#   'year': '1973',
#   'artist': 'Bruce Springsteen',
#   'genre': 'None'},
#  {'number': '134',
#   'album': 'Ready to Die',
#   'year': '1994',
#   'artist': 'The Notorious B.I.G.',
#   'genre': 'Thug Rap'},
#  {'number': '135',
#   'album': 'Slanted and Enchanted',
#   'year': '1992',
#   'artist': 'Pavement',
#   'genre': 'Alternative Rock'},
#  {'number': '136',
#   'album': 'Greatest Hits',
#   'year': '1974',
#   'artist': 'Elton John',
#   'genre': 'Classic Rock'},
#  {'number': '137',
#   'album': 'Tim',
#   'year': '1985',
#   'artist': 'The Replacements',
#   'genre': 'Indie Rock'},
#  {'number': '138',
#   'album': 'The Chronic',
#   'year': '1992',
#   'artist': 'Dr. Dre',
#   'genre': 'Gangsta'},
#  {'number': '139',
#   'album': 'Rejuvenation',
#   'year': '1974',
#   'artist': 'The Meters',
#   'genre': 'Bayou Funk, Soul'},
#  {'number': '140',
#   'album': 'Parallel Lines',
#   'year': '1978',
#   'artist': 'Blondie',
#   'genre': 'New Wave, Pop Rock, Punk, Disco'},
#  {'number': '141',
#   'album': 'Live at the Regal',
#   'year': '1965',
#   'artist': 'B.B. King',
#   'genre': 'Chicago Blues'},
#  {'number': '142',
#   'album': 'A Christmas Gift for You From Phil Spector',
#   'year': '1963',
#   'artist': 'Phil Spector',
#   'genre': 'Pop Rock'},
#  {'number': '143',
#   'album': 'Gris-Gris',
#   'year': '1968',
#   'artist': 'Dr. John, the Night Tripper',
#   'genre': 'Soul-Jazz, Louisiana Blues, Fusion, Bayou Funk'},
#  {'number': '144',
#   'album': 'Straight Outta Compton',
#   'year': '1988',
#   'artist': 'N.W.A',
#   'genre': 'Gangsta'},
#  {'number': '145',
#   'album': 'Aja',
#   'year': '1977',
#   'artist': 'Steely Dan',
#   'genre': 'Jazz-Rock, Classic Rock'},
#  {'number': '146',
#   'album': 'Surrealistic Pillow',
#   'year': '1967',
#   'artist': 'Jefferson Airplane',
#   'genre': 'Folk Rock, Psychedelic Rock'},
#  {'number': '147',
#   'album': 'Deja vu',
#   'year': '1970',
#   'artist': 'Crosby, Stills, Nash & Young',
#   'genre': 'Classic Rock'},
#  {'number': '148',
#   'album': 'Houses of the Holy',
#   'year': '1973',
#   'artist': 'Led Zeppelin',
#   'genre': 'Classic Rock'},
#  {'number': '149',
#   'album': 'Santana',
#   'year': '1969',
#   'artist': 'Santana',
#   'genre': 'Afro-Cuban, Psychedelic Rock'},
#  {'number': '150',
#   'album': 'Darkness on the Edge of Town',
#   'year': '1978',
#   'artist': 'Bruce Springsteen',
#   'genre': 'Pop Rock'},
#  {'number': '151',
#   'album': 'Funeral',
#   'year': '2004',
#   'artist': 'Arcade Fire',
#   'genre': 'Indie Rock'},
#  {'number': '152',
#   'album': "The B 52's",
#   'year': '1979',
#   'artist': "The B 52's",
#   'genre': 'New Wave, Punk, Mod'},
#  {'number': '153',
#   'album': 'The Low End Theory',
#   'year': '1991',
#   'artist': 'A Tribe Called Quest',
#   'genre': 'Conscious'},
#  {'number': '154',
#   'album': "Moanin' in the Moonlight",
#   'year': '1958',
#   'artist': "Howlin' Wolf",
#   'genre': 'Chicago Blues'},
#  {'number': '155',
#   'album': 'Pretenders',
#   'year': '1980',
#   'artist': 'Pretenders',
#   'genre': 'Alternative Rock, New Wave'},
#  {'number': '156',
#   'album': "Paul's Boutique",
#   'year': '1989',
#   'artist': 'Beastie Boys',
#   'genre': 'Alternative Rock, Pop Rap, Psychedelic'},
#  {'number': '157',
#   'album': 'Closer',
#   'year': '1980',
#   'artist': 'Joy Division',
#   'genre': 'Post-Punk, New Wave'},
#  {'number': '158',
#   'album': 'Captain Fantastic and the Brown Dirt Cowboy',
#   'year': '1975',
#   'artist': 'Elton John',
#   'genre': 'Pop Rock, Classic Rock'},
#  {'number': '159',
#   'album': 'Alive!',
#   'year': '1975',
#   'artist': 'KISS',
#   'genre': 'Hard Rock, Glam'},
#  {'number': '160',
#   'album': 'Electric Warrior',
#   'year': '1971',
#   'artist': 'T. Rex',
#   'genre': 'Glam, Classic Rock'},
#  {'number': '161',
#   'album': 'The Dock of the Bay',
#   'year': '1968',
#   'artist': 'Otis Redding',
#   'genre': 'Rhythm & Blues, Soul'},
#  {'number': '162',
#   'album': 'OK Computer',
#   'year': '1997',
#   'artist': 'Radiohead',
#   'genre': 'Alternative Rock'},
#  {'number': '163',
#   'album': '1999',
#   'year': '1982',
#   'artist': 'Prince',
#   'genre': 'None'},
#  {'number': '165',
#   'album': "Let's Get It On",
#   'year': '1973',
#   'artist': 'Marvin Gaye',
#   'genre': 'Soul'},
#  {'number': '166',
#   'album': 'Imperial Bedroom',
#   'year': '1982',
#   'artist': 'Elvis Costello & The Attractions',
#   'genre': 'Alternative Rock, New Wave'},
#  {'number': '167',
#   'album': 'Master of Puppets',
#   'year': '1986',
#   'artist': 'Metallica',
#   'genre': 'Thrash, Speed Metal'},
#  {'number': '168',
#   'album': 'My Aim Is True',
#   'year': '1977',
#   'artist': 'Elvis Costello',
#   'genre': 'New Wave, Pop Rock'},
#  {'number': '169',
#   'album': 'Exodus',
#   'year': '1977',
#   'artist': 'Bob Marley & The Wailers',
#   'genre': 'Reggae, Roots Reggae'},
#  {'number': '170',
#   'album': 'Live at Leeds',
#   'year': '1970',
#   'artist': 'The Who',
#   'genre': 'Classic Rock, Blues Rock, Hard Rock'},
#  {'number': '171',
#   'album': 'The Notorious Byrd Brothers',
#   'year': '1968',
#   'artist': 'The Byrds',
#   'genre': 'Psychedelic Rock, Folk Rock, Country Rock, Pop Rock'},
#  {'number': '172',
#   'album': 'Every Picture Tells a Story',
#   'year': '1971',
#   'artist': 'Rod Stewart',
#   'genre': 'Pop Rock'},
#  {'number': '173',
#   'album': 'Something/Anything?',
#   'year': '1972',
#   'artist': 'Todd Rundgren',
#   'genre': 'Power Pop, Pop Rock, Prog Rock'},
#  {'number': '174',
#   'album': 'Desire',
#   'year': '1976',
#   'artist': 'Bob Dylan',
#   'genre': 'Folk Rock'},
#  {'number': '175',
#   'album': 'Close to You',
#   'year': '1970',
#   'artist': 'Carpenters',
#   'genre': 'Pop Rock, Vocal'},
#  {'number': '176',
#   'album': 'Rocks',
#   'year': '1976',
#   'artist': 'Aerosmith',
#   'genre': 'Hard Rock, Classic Rock'},
#  {'number': '177',
#   'album': 'One Nation Under a Groove',
#   'year': '1978',
#   'artist': 'Funkadelic',
#   'genre': 'P.Funk'},
#  {'number': '178',
#   'album': 'The Anthology: 1961-1977',
#   'year': '1992',
#   'artist': 'Curtis Mayfield and The Impressions',
#   'genre': 'Rhythm & Blues, Soul, Funk'},
#  {'number': '179',
#   'album': 'The Definitive Collection',
#   'year': '2001',
#   'artist': 'ABBA',
#   'genre': 'Europop, Synth-pop, Disco'},
#  {'number': '180',
#   'album': 'The Rolling Stones, Now!',
#   'year': '1965',
#   'artist': 'The Rolling Stones',
#   'genre': 'Pop Rock, Rhythm & Blues, Rock & Roll'},
#  {'number': '181',
#   'album': 'Natty Dread',
#   'year': '1974',
#   'artist': 'Bob Marley & The Wailers',
#   'genre': 'Reggae, Roots Reggae'},
#  {'number': '182',
#   'album': 'Fleetwood Mac',
#   'year': '1975',
#   'artist': 'Fleetwood Mac',
#   'genre': 'Folk Rock, Pop Rock'},
#  {'number': '183',
#   'album': 'Red Headed Stranger',
#   'year': '1975',
#   'artist': 'Willie Nelson',
#   'genre': 'Country'},
#  {'number': '184',
#   'album': 'The Immaculate Collection',
#   'year': '1990',
#   'artist': 'Madonna',
#   'genre': 'Synth-pop'},
#  {'number': '185',
#   'album': 'The Stooges',
#   'year': '1969',
#   'artist': 'The Stooges',
#   'genre': 'Garage Rock, Punk'},
#  {'number': '186',
#   'album': 'Fresh',
#   'year': '1973',
#   'artist': 'Sly & The Family Stone',
#   'genre': 'Rhythm & Blues, Funk'},
#  {'number': '187',
#   'album': 'So',
#   'year': '1986',
#   'artist': 'Peter Gabriel',
#   'genre': 'Art Rock, Pop Rock, Synth-pop, Funk'},
#  {'number': '188',
#   'album': 'Buffalo Springfield Again',
#   'year': '1967',
#   'artist': 'Buffalo Springfield',
#   'genre': 'Country Rock'},
#  {'number': '189',
#   'album': 'Happy Trails',
#   'year': '1969',
#   'artist': 'Quicksilver Messenger Service',
#   'genre': 'Acid Rock, Psychedelic Rock'},
#  {'number': '190',
#   'album': 'From Elvis in Memphis',
#   'year': '1969',
#   'artist': 'Elvis Presley',
#   'genre': 'Country, Soul'},
#  {'number': '191',
#   'album': 'Fun House',
#   'year': '1970',
#   'artist': 'The Stooges',
#   'genre': 'Garage Rock, Punk'},
#  {'number': '192',
#   'album': 'The Gilded Palace of Sin',
#   'year': '1969',
#   'artist': 'The Flying Burrito Brothers',
#   'genre': 'Country Rock'},
#  {'number': '193',
#   'album': 'Dookie',
#   'year': '1994',
#   'artist': 'Green Day',
#   'genre': 'Alternative Rock, Pop Punk, Punk'},
#  {'number': '194',
#   'album': 'Transformer',
#   'year': '1972',
#   'artist': 'Lou Reed',
#   'genre': 'Glam'},
#  {'number': '195',
#   'album': 'The Beano Album',
#   'year': '1966',
#   'artist': 'John Mayall & The Bluesbreakers',
#   'genre': 'Blues Rock,Electric Blues,Harmonica Blues'},
#  {'number': '197',
#   'album': 'Murmur',
#   'year': '1983',
#   'artist': 'R.E.M.',
#   'genre': 'Alternative Rock'},
#  {'number': '199',
#   'album': 'Is This It',
#   'year': '2001',
#   'artist': 'The Strokes',
#   'genre': 'Indie Rock'},
#  {'number': '200',
#   'album': 'Highway to Hell',
#   'year': '1979',
#   'artist': 'AC/DC',
#   'genre': 'Hard Rock'},
#  {'number': '201',
#   'album': 'The Downward Spiral',
#   'year': '1994',
#   'artist': 'Nine Inch Nails',
#   'genre': 'Industrial'},
#  {'number': '202',
#   'album': 'Parsley, Sage, Rosemary and Thyme',
#   'year': '1966',
#   'artist': 'Simon & Garfunkel',
#   'genre': 'Folk Rock, Pop Rock'},
#  {'number': '203',
#   'album': 'Bad',
#   'year': '1987',
#   'artist': 'Michael Jackson',
#   'genre': 'Pop Rock, Ballad, Funk, Soul'},
#  {'number': '204',
#   'album': 'Modern Times',
#   'year': '2006',
#   'artist': 'Bob Dylan',
#   'genre': 'Blues Rock, Folk Rock'},
#  {'number': '205',
#   'album': 'Wheels of Fire',
#   'year': '1968',
#   'artist': 'Cream',
#   'genre': 'Blues Rock, Psychedelic Rock, Classic Rock'},
#  {'number': '206',
#   'album': 'Dirty Mind',
#   'year': '1980',
#   'artist': 'Prince',
#   'genre': 'None'},
#  {'number': '207',
#   'album': 'Abraxas',
#   'year': '1970',
#   'artist': 'Santana',
#   'genre': 'Fusion, Hard Rock, Psychedelic Rock'},
#  {'number': '208',
#   'album': 'Tea for the Tillerman',
#   'year': '1970',
#   'artist': 'Cat Stevens',
#   'genre': 'Folk Rock, Pop Rock'},
#  {'number': '209',
#   'album': 'Ten',
#   'year': '1991',
#   'artist': 'Pearl Jam',
#   'genre': 'Grunge'},
#  {'number': '210',
#   'album': 'Everybody Knows This Is Nowhere',
#   'year': '1969',
#   'artist': 'Neil Young & Crazy Horse',
#   'genre': 'Folk Rock, Country Rock, Classic Rock'},
#  {'number': '211',
#   'album': 'Wish You Were Here',
#   'year': '1975',
#   'artist': 'Pink Floyd',
#   'genre': 'Classic Rock, Prog Rock'},
#  {'number': '212',
#   'album': 'Crooked Rain Crooked Rain',
#   'year': '1994',
#   'artist': 'Pavement',
#   'genre': 'Alternative Rock, Indie Rock'},
#  {'number': '213',
#   'album': 'Tattoo You',
#   'year': '1981',
#   'artist': 'The Rolling Stones',
#   'genre': 'Classic Rock'},
#  {'number': '215',
#   'album': 'New York Dolls',
#   'year': '1973',
#   'artist': 'New York Dolls',
#   'genre': 'Glam'},
#  {'number': '216',
#   'album': 'Bo Diddley / Go Bo Diddley',
#   'year': '1986',
#   'artist': 'Bo Diddley',
#   'genre': 'Rhythm & Blues, Rock & Roll'},
#  {'number': '217',
#   'album': 'Two Steps From the Blues',
#   'year': '1961',
#   'artist': 'Bobby "Blue" Bland',
#   'genre': 'Rhythm & Blues, Soul'},
#  {'number': '218',
#   'album': 'The Queen Is Dead',
#   'year': '1986',
#   'artist': 'The Smiths',
#   'genre': 'Indie Rock'},
#  {'number': '219',
#   'album': 'Licensed to Ill',
#   'year': '1986',
#   'artist': 'Beastie Boys',
#   'genre': 'None'},
#  {'number': '220',
#   'album': 'Look-Ka Py Py',
#   'year': '1970',
#   'artist': 'The Meters',
#   'genre': 'Bayou Funk, Soul, Funk'},
#  {'number': '221',
#   'album': 'Loveless',
#   'year': '1991',
#   'artist': 'My Bloody Valentine',
#   'genre': 'Alternative Rock, Shoegaze'},
#  {'number': '222',
#   'album': 'New Orleans Piano',
#   'year': '1972',
#   'artist': 'Professor Longhair',
#   'genre': 'Piano Blues'},
#  {'number': '223',
#   'album': 'War',
#   'year': '1983',
#   'artist': 'U2',
#   'genre': 'Pop Rock'},
#  {'number': '224',
#   'album': 'The Neil Diamond Collection',
#   'year': '1999',
#   'artist': 'Neil Diamond',
#   'genre': 'Soft Rock, Ballad'},
#  {'number': '225',
#   'album': 'American Idiot',
#   'year': '2004',
#   'artist': 'Green Day',
#   'genre': 'Pop Rock, Punk'},
#  {'number': '226',
#   'album': 'Nebraska',
#   'year': '1982',
#   'artist': 'Bruce Springsteen',
#   'genre': 'Acoustic'},
#  {'number': '227',
#   'album': 'Doolittle',
#   'year': '1989',
#   'artist': 'Pixies',
#   'genre': 'Indie Rock'},
#  {'number': '228',
#   'album': 'Paid in Full',
#   'year': '1987',
#   'artist': 'Eric B. & Rakim',
#   'genre': 'None'},
#  {'number': '229',
#   'album': 'Toys in the Attic',
#   'year': '1975',
#   'artist': 'Aerosmith',
#   'genre': 'Hard Rock, Blues Rock'},
#  {'number': '230',
#   'album': 'Nick of Time',
#   'year': '1989',
#   'artist': 'Bonnie Raitt',
#   'genre': 'Blues Rock, Pop Rock'},
#  {'number': '231',
#   'album': 'A Night at the Opera',
#   'year': '1975',
#   'artist': 'Queen',
#   'genre': 'Hard Rock, Pop Rock, Prog Rock'},
#  {'number': '233',
#   'album': 'Mr. Tambourine Man',
#   'year': '1965',
#   'artist': 'The Byrds',
#   'genre': 'Folk Rock, Garage Rock, Pop Rock'},
#  {'number': '234',
#   'album': 'Bookends',
#   'year': '1968',
#   'artist': 'Simon & Garfunkel',
#   'genre': 'Folk Rock, Classic Rock'},
#  {'number': '235',
#   'album': 'The Ultimate Collection',
#   'year': '2000',
#   'artist': 'Patsy Cline',
#   'genre': 'None'},
#  {'number': '236',
#   'album': 'Mr. Excitement!',
#   'year': '1992',
#   'artist': 'Jackie Wilson',
#   'genre': 'None'},
#  {'number': '237',
#   'album': 'My Generation',
#   'year': '1965',
#   'artist': 'The Who',
#   'genre': 'Mod'},
#  {'number': '238',
#   'album': "Howlin' Wolf",
#   'year': '1962',
#   'artist': "Howlin' Wolf",
#   'genre': 'None'},
#  {'number': '239',
#   'album': 'Like a Prayer',
#   'year': '1989',
#   'artist': 'Madonna',
#   'genre': 'Synth-pop'},
#  {'number': '240',
#   'album': "Can't Buy a Thrill",
#   'year': '1972',
#   'artist': 'Steely Dan',
#   'genre': 'Classic Rock'},
#  {'number': '241',
#   'album': 'Let It Be',
#   'year': '1984',
#   'artist': 'The Replacements',
#   'genre': 'Alternative Rock, Power Pop, Punk, Indie Rock'},
#  {'number': '242',
#   'album': 'Run D.M.C.',
#   'year': '1984',
#   'artist': 'Run D.M.C.',
#   'genre': 'None'},
#  {'number': '243',
#   'album': 'Black Sabbath',
#   'year': '1970',
#   'artist': 'Black Sabbath',
#   'genre': 'Blues Rock, Heavy Metal'},
#  {'number': '244',
#   'album': 'The Marshall Mathers LP',
#   'year': '2000',
#   'artist': 'Eminem',
#   'genre': 'Pop Rap, Hardcore Hip-Hop, Horrorcore'},
#  {'number': '246',
#   'album': 'Freak Out!',
#   'year': '1966',
#   'artist': 'The Mothers of Invention',
#   'genre': 'Musique Concr?te, Avantgarde, Symphonic Rock, Rhythm & Blues, Psychedelic Rock, Experimental, Parody'},
#  {'number': '247',
#   'album': 'Live/Dead',
#   'year': '1969',
#   'artist': 'The Grateful Dead',
#   'genre': 'Folk Rock, Country Rock, Psychedelic Rock, Experimental'},
#  {'number': '248',
#   'album': 'The Shape of Jazz to Come',
#   'year': '1959',
#   'artist': 'Ornette Coleman',
#   'genre': 'Free Jazz'},
#  {'number': '249',
#   'album': 'Automatic for the People',
#   'year': '1992',
#   'artist': 'R.E.M.',
#   'genre': 'Alternative Rock'},
#  {'number': '250',
#   'album': 'Reasonable Doubt',
#   'year': '1996',
#   'artist': 'Jay Z',
#   'genre': 'None'},
#  {'number': '251',
#   'album': 'Low',
#   'year': '1977',
#   'artist': 'David Bowie',
#   'genre': 'Art Rock, Ambient, Experimental'},
#  {'number': '252',
#   'album': 'The Blueprint',
#   'year': '2001',
#   'artist': 'Jay Z',
#   'genre': 'None'},
#  {'number': '253',
#   'album': 'The River',
#   'year': '1980',
#   'artist': 'Bruce Springsteen',
#   'genre': 'Folk Rock, Pop Rock, Classic Rock'},
#  {'number': '254',
#   'album': 'Complete & Unbelievable: The Otis Redding Dictionary of Soul',
#   'year': '1966',
#   'artist': 'Otis Redding',
#   'genre': 'Soul'},
#  {'number': '255',
#   'album': 'Metallica ("The Black Album")',
#   'year': '1991',
#   'artist': 'Metallica',
#   'genre': 'Heavy Metal'},
#  {'number': '257',
#   'album': 'Whitney Houston',
#   'year': '1985',
#   'artist': 'Whitney Houston',
#   'genre': 'Synth-pop, Rhythm & Blues'},
#  {'number': '258',
#   'album': 'The Kinks Are The Village Green Preservation Society',
#   'year': '1968',
#   'artist': 'The Kinks',
#   'genre': 'Psychedelic Rock, Pop Rock'},
#  {'number': '259',
#   'album': 'The Velvet Rope',
#   'year': '1997',
#   'artist': 'Janet',
#   'genre': 'RnB/Swing, Downtempo'},
#  {'number': '260',
#   'album': 'Stardust',
#   'year': '1978',
#   'artist': 'Willie Nelson',
#   'genre': 'Vocal'},
#  {'number': '261',
#   'album': 'American Beauty',
#   'year': '1970',
#   'artist': 'Grateful Dead',
#   'genre': 'Folk Rock'},
#  {'number': '262',
#   'album': 'Crosby, Stills & Nash',
#   'year': '1969',
#   'artist': 'Crosby, Stills & Nash',
#   'genre': 'Folk Rock, Classic Rock'},
#  {'number': '263',
#   'album': 'Tracy Chapman',
#   'year': '1988',
#   'artist': 'Tracy Chapman',
#   'genre': 'None'},
#  {'number': '264',
#   'album': "Workingman's Dead",
#   'year': '1970',
#   'artist': 'Grateful Dead',
#   'genre': 'Folk Rock, Country Rock, Classic Rock'},
#  {'number': '265',
#   'album': 'The Genius of Ray Charles',
#   'year': '1959',
#   'artist': 'Ray Charles',
#   'genre': 'Soul-Jazz, Big Band'},
#  {'number': '266',
#   'album': 'Child Is Father to the Man',
#   'year': '1968',
#   'artist': 'Blood, Sweat & Tears',
#   'genre': 'Blues Rock, Jazz-Rock, Classic Rock'},
#  {'number': '267',
#   'album': 'Quadrophenia',
#   'year': '1973',
#   'artist': 'The Who',
#   'genre': 'Hard Rock, Classic Rock, Mod'},
#  {'number': '268',
#   'album': 'Paul Simon',
#   'year': '1972',
#   'artist': 'Paul Simon',
#   'genre': 'Folk Rock, Pop Rock'},
#  {'number': '269',
#   'album': 'Psychocandy',
#   'year': '1985',
#   'artist': 'The Jesus and Mary Chain',
#   'genre': 'Noise'},
#  {'number': '270',
#   'album': 'Some Girls',
#   'year': '1978',
#   'artist': 'The Rolling Stones',
#   'genre': 'Blues Rock, Rock & Roll, Classic Rock, Disco'},
#  {'number': '271',
#   'album': 'The Beach Boys Today!',
#   'year': '1965',
#   'artist': 'The Beach Boys',
#   'genre': 'Pop Rock, Psychedelic Rock'},
#  {'number': '272',
#   'album': 'Dig Me Out',
#   'year': '1997',
#   'artist': 'Sleater Kinney',
#   'genre': 'Indie Rock'},
#  {'number': '273',
#   'album': 'Going to a Go-Go',
#   'year': '1966',
#   'artist': 'Smokey Robinson & The Miracles',
#   'genre': 'Soul'},
#  {'number': '274',
#   'album': 'Nightbirds',
#   'year': '1974',
#   'artist': 'LaBelle',
#   'genre': 'Funk, Disco'},
#  {'number': '275',
#   'album': 'The Slim Shady LP',
#   'year': '1999',
#   'artist': 'Eminem',
#   'genre': 'None'},
#  {'number': '276',
#   'album': 'Mothership Connection',
#   'year': '1975',
#   'artist': 'Parliament',
#   'genre': 'P.Funk, Funk'},
#  {'number': '277',
#   'album': 'Rhythm Nation 1814',
#   'year': '1989',
#   'artist': 'Janet Jackson',
#   'genre': 'RnB/Swing, Downtempo, Synth-pop'},
#  {'number': '279',
#   'album': 'Aladdin Sane',
#   'year': '1973',
#   'artist': 'David Bowie',
#   'genre': 'Glam'},
#  {'number': '280',
#   'album': "All That You Can't Leave Behind",
#   'year': '2000',
#   'artist': 'U2',
#   'genre': 'Pop Rock'},
#  {'number': '281',
#   'album': 'My Life',
#   'year': '1994',
#   'artist': 'Mary J. Blige',
#   'genre': 'RnB/Swing'},
#  {'number': '282',
#   'album': 'Folk Singer',
#   'year': '1964',
#   'artist': 'Muddy Waters',
#   'genre': 'Delta Blues'},
#  {'number': '283',
#   'album': "Can't Get Enough",
#   'year': '1974',
#   'artist': 'Barry White',
#   'genre': 'Soul, Disco'},
#  {'number': '284',
#   'album': 'The Cars',
#   'year': '1978',
#   'artist': 'The Cars',
#   'genre': 'New Wave, Pop Rock, Synth-pop'},
#  {'number': '285',
#   'album': 'Music of My Mind',
#   'year': '1972',
#   'artist': 'Stevie Wonder',
#   'genre': 'Soul-Jazz, Soul'},
#  {'number': '286',
#   'album': "I'm Still in Love With You",
#   'year': '1972',
#   'artist': 'Al Green',
#   'genre': 'Rhythm & Blues, Soul'},
#  {'number': '287',
#   'album': 'Los Angeles',
#   'year': '1980',
#   'artist': 'X',
#   'genre': 'Punk, Rock & Roll'},
#  {'number': '288',
#   'album': 'Anthem of the Sun',
#   'year': '1968',
#   'artist': 'Grateful Dead',
#   'genre': 'Psychedelic Rock'},
#  {'number': '290',
#   'album': 'Call Me',
#   'year': '1973',
#   'artist': 'Al Green',
#   'genre': 'Rhythm & Blues, Soul'},
#  {'number': '291',
#   'album': 'Talking Heads: 77',
#   'year': '1977',
#   'artist': 'Talking Heads',
#   'genre': 'New Wave'},
#  {'number': '292',
#   'album': 'The Basement Tapes',
#   'year': '1975',
#   'artist': 'Bob Dylan and the Band',
#   'genre': 'Folk Rock, Country Rock, Classic Rock'},
#  {'number': '293',
#   'album': 'White Light/White Heat',
#   'year': '1968',
#   'artist': 'The Velvet Underground',
#   'genre': 'Avantgarde, Experimental'},
#  {'number': '294',
#   'album': 'Kick Out the Jams',
#   'year': '1969',
#   'artist': 'MC5',
#   'genre': 'Garage Rock, Hard Rock, Punk, Blues Rock'},
#  {'number': '295',
#   'album': 'Songs of Love and Hate',
#   'year': '1970',
#   'artist': 'Leonard Cohen',
#   'genre': 'Folk Rock, Folk, Ballad'},
#  {'number': '296',
#   'album': 'Meat Is Murder',
#   'year': '1985',
#   'artist': 'The Smiths',
#   'genre': 'Alternative Rock, Indie Rock'},
#  {'number': '297',
#   'album': "We're Only in It for the Money",
#   'year': '1968',
#   'artist': 'The Mothers of Invention',
#   'genre': 'Modern Classical, Avantgarde, Psychedelic Rock, Experimental, Parody'},
#  {'number': '298',
#   'album': 'The College Dropout',
#   'year': '2003',
#   'artist': 'Kanye West',
#   'genre': 'Pop Rap, Conscious, Contemporary R&B'},
#  {'number': '299',
#   'album': 'Weezer (Blue Album)',
#   'year': '1994',
#   'artist': 'Weezer',
#   'genre': 'Alternative Rock, Emo'},
#  {'number': '300',
#   'album': 'Master of Reality',
#   'year': '1971',
#   'artist': 'Black Sabbath',
#   'genre': 'Hard Rock, Heavy Metal'},
#  {'number': '301',
#   'album': 'Coat of Many Colors',
#   'year': '1971',
#   'artist': 'Dolly Parton',
#   'genre': 'Country'},
#  {'number': '302',
#   'album': 'Fear of a Black Planet',
#   'year': '1990',
#   'artist': 'Public Enemy',
#   'genre': 'Conscious'},
#  {'number': '303',
#   'album': 'John Wesley Harding',
#   'year': '1967',
#   'artist': 'Bob Dylan',
#   'genre': 'Folk Rock, Country Rock'},
#  {'number': '304',
#   'album': 'Grace',
#   'year': '1994',
#   'artist': 'Jeff Buckley',
#   'genre': 'Alternative Rock, Folk Rock'},
#  {'number': '305',
#   'album': 'Car Wheels on a Gravel Road',
#   'year': '1998',
#   'artist': 'Lucinda Williams',
#   'genre': 'Country, Folk'},
#  {'number': '306',
#   'album': 'Odelay',
#   'year': '1996',
#   'artist': 'Beck',
#   'genre': 'Electro, Downtempo, Hip Hop, Disco, Afrobeat, Abstract'},
#  {'number': '307',
#   'album': "A Hard Day's Night",
#   'year': '1964',
#   'artist': 'The Beatles',
#   'genre': 'Soundtrack, Beat, Pop Rock'},
#  {'number': '309',
#   'album': 'Willy and the Poor Boys',
#   'year': '1969',
#   'artist': 'Creedence Clearwater Revival',
#   'genre': 'Blues Rock, Rock & Roll, Classic Rock'},
#  {'number': '310',
#   'album': 'Blood Sugar Sex Magik',
#   'year': '1991',
#   'artist': 'Red Hot Chili Peppers',
#   'genre': 'Alternative Rock, Funk Metal'},
#  {'number': '311',
#   'album': 'The Sun Records Collection',
#   'year': '1994',
#   'artist': 'Various',
#   'genre': 'Country Blues, Rock & Roll, Rockabilly'},
#  {'number': '312',
#   'album': "Nothing's Shocking",
#   'year': '1988',
#   'artist': "Jane's Addiction",
#   'genre': 'Alternative Rock'},
#  {'number': '313',
#   'album': 'MTV Unplugged in New York',
#   'year': '1994',
#   'artist': 'Nirvana',
#   'genre': 'Folk Rock, Acoustic, Grunge'},
#  {'number': '314',
#   'album': 'The Miseducation of Lauryn Hill',
#   'year': '1998',
#   'artist': 'Lauryn Hill',
#   'genre': 'RnB/Swing, Conscious'},
#  {'number': '315',
#   'album': 'Damn the Torpedoes',
#   'year': '1979',
#   'artist': 'Tom Petty and the Heartbreakers',
#   'genre': 'Soft Rock, Hard Rock, Pop Rock'},
#  {'number': '316',
#   'album': 'The Velvet Underground',
#   'year': '1969',
#   'artist': 'The Velvet Underground',
#   'genre': 'Garage Rock, Art Rock, Experimental'},
#  {'number': '317',
#   'album': 'Surfer Rosa',
#   'year': '1988',
#   'artist': 'Pixies',
#   'genre': 'Alternative Rock'},
#  {'number': '318',
#   'album': 'Back Stabbers',
#   'year': '1972',
#   'artist': "The O'Jays",
#   'genre': 'Soul'},
#  {'number': '319',
#   'album': "Burnin'",
#   'year': '1973',
#   'artist': 'The Wailers',
#   'genre': 'Reggae'},
#  {'number': '320',
#   'album': 'Amnesiac',
#   'year': '2001',
#   'artist': 'Radiohead',
#   'genre': 'Alternative Rock, Experimental'},
#  {'number': '321',
#   'album': 'Pink Moon',
#   'year': '1972',
#   'artist': 'Nick Drake',
#   'genre': 'Folk, Folk Rock, Acoustic'},
#  {'number': '322',
#   'album': 'Sail Away',
#   'year': '1972',
#   'artist': 'Randy Newman',
#   'genre': 'None'},
#  {'number': '323',
#   'album': 'Ghost in the Machine',
#   'year': '1981',
#   'artist': 'The Police',
#   'genre': 'Alternative Rock, New Wave, Pop Rock'},
#  {'number': '324',
#   'album': 'Station to Station',
#   'year': '1976',
#   'artist': 'David Bowie',
#   'genre': 'Classic Rock, Soul, Funk, Art Rock'},
#  {'number': '325',
#   'album': 'Slowhand',
#   'year': '1977',
#   'artist': 'Eric Clapton',
#   'genre': 'None'},
#  {'number': '326',
#   'album': 'Disintegration',
#   'year': '1989',
#   'artist': 'The Cure',
#   'genre': 'New Wave, Alternative Rock'},
#  {'number': '327',
#   'album': 'Exile in Guyville',
#   'year': '1993',
#   'artist': 'Liz Phair',
#   'genre': 'Lo-Fi, Indie Rock'},
#  {'number': '328',
#   'album': 'Daydream Nation',
#   'year': '1988',
#   'artist': 'Sonic Youth',
#   'genre': 'Alternative Rock, Indie Rock'},
#  {'number': '329',
#   'album': 'In the Jungle Groove',
#   'year': '1986',
#   'artist': 'James Brown',
#   'genre': 'Soul, Funk'},
#  {'number': '330',
#   'album': "Tonight's the Night",
#   'year': '1975',
#   'artist': 'Neil Young',
#   'genre': 'Blues Rock, Folk Rock, Classic Rock'},
#  {'number': '331',
#   'album': 'Help!',
#   'year': '1965',
#   'artist': 'The Beatles',
#   'genre': 'Beat, Soundtrack, Pop Rock'},
#  {'number': '332',
#   'album': 'Shoot Out the Lights',
#   'year': '1982',
#   'artist': 'Richard & Linda Thompson',
#   'genre': 'Folk Rock'},
#  {'number': '333',
#   'album': 'Wild Gift',
#   'year': '1981',
#   'artist': 'X',
#   'genre': 'Rock & Roll, Punk'},
#  {'number': '334',
#   'album': 'Squeezing Out Sparks',
#   'year': '1979',
#   'artist': 'Graham Parker & The Rumour',
#   'genre': 'None'},
#  {'number': '335',
#   'album': 'Superunknown',
#   'year': '1994',
#   'artist': 'Soundgarden',
#   'genre': 'Alternative Rock'},
#  {'number': '336',
#   'album': 'In Rainbows',
#   'year': '2007',
#   'artist': 'Radiohead',
#   'genre': 'Alternative Rock, Art Rock'},
#  {'number': '337',
#   'album': 'Aqualung',
#   'year': '1971',
#   'artist': 'Jethro Tull',
#   'genre': 'Classic Rock, Prog Rock'},
#  {'number': '338',
#   'album': 'Cheap Thrills',
#   'year': '1968',
#   'artist': 'Big Brother & the Holding Company',
#   'genre': 'Folk Rock, Blues Rock, Psychedelic Rock'},
#  {'number': '339',
#   'album': 'The Heart of Saturday Night',
#   'year': '1974',
#   'artist': 'Tom Waits',
#   'genre': 'Contemporary Jazz, Spoken Word'},
#  {'number': '340',
#   'album': 'Damaged',
#   'year': '1981',
#   'artist': 'Black Flag',
#   'genre': 'Hardcore, Punk'},
#  {'number': '341',
#   'album': 'Play',
#   'year': '1999',
#   'artist': 'Moby',
#   'genre': 'Breakbeat, Leftfield, Downtempo'},
#  {'number': '342',
#   'album': 'Violator',
#   'year': '1990',
#   'artist': 'Depeche Mode',
#   'genre': 'Synth-pop'},
#  {'number': '343',
#   'album': 'Bat Out of Hell',
#   'year': '1977',
#   'artist': 'Meat Loaf',
#   'genre': 'Pop Rock'},
#  {'number': '344',
#   'album': 'Berlin',
#   'year': '1973',
#   'artist': 'Lou Reed',
#   'genre': 'Hard Rock'},
#  {'number': '345',
#   'album': 'Stop Making Sense',
#   'year': '1984',
#   'artist': 'Talking Heads',
#   'genre': 'Funk, Indie Rock, New Wave'},
#  {'number': '347',
#   'album': 'The Piper at the Gates of Dawn',
#   'year': '1967',
#   'artist': 'Pink Floyd',
#   'genre': 'Psychedelic Rock'},
#  {'number': '348',
#   'album': 'Muddy Waters at Newport 1960',
#   'year': '1960',
#   'artist': 'Muddy Waters',
#   'genre': 'Blues Rock, Chicago Blues'},
#  {'number': '349',
#   'album': 'The Black Album',
#   'year': '2003',
#   'artist': 'Jay Z',
#   'genre': 'None'},
#  {'number': '350',
#   'album': 'Roger the Engineer',
#   'year': '1966',
#   'artist': 'The Yardbirds',
#   'genre': 'Blues Rock, Pop Rock'},
#  {'number': '351',
#   'album': 'Rust Never Sleeps',
#   'year': '1979',
#   'artist': 'Neil Young & Crazy Horse',
#   'genre': 'Hard Rock, Arena Rock'},
#  {'number': '352',
#   'album': 'Brothers in Arms',
#   'year': '1985',
#   'artist': 'Dire Straits',
#   'genre': 'AOR, Classic Rock'},
#  {'number': '353',
#   'album': 'My Beautiful Dark Twisted Fantasy',
#   'year': '2010',
#   'artist': 'Kanye West',
#   'genre': 'None'},
#  {'number': '354',
#   'album': '52nd Street',
#   'year': '1978',
#   'artist': 'Billy Joel',
#   'genre': 'Pop Rock, Ballad, Latin Jazz'},
#  {'number': '356',
#   'album': '12 Songs',
#   'year': '1970',
#   'artist': 'Randy Newman',
#   'genre': 'Pop Rock, Vocal'},
#  {'number': '357',
#   'album': 'Between the Buttons',
#   'year': '1967',
#   'artist': 'The Rolling Stones',
#   'genre': 'Blues Rock, Psychedelic Rock, Pop Rock'},
#  {'number': '358',
#   'album': 'Sketches of Spain',
#   'year': '1960',
#   'artist': 'Miles Davis',
#   'genre': 'Modal'},
#  {'number': '360',
#   'album': 'Singles Going Steady',
#   'year': '1979',
#   'artist': 'Buzzcocks',
#   'genre': 'Punk'},
#  {'number': '361',
#   'album': 'Stankonia',
#   'year': '2000',
#   'artist': 'OutKast',
#   'genre': 'Gangsta, P.Funk, Crunk, Conscious'},
#  {'number': '362',
#   'album': 'Siamese Dream',
#   'year': '1993',
#   'artist': 'The Smashing Pumpkins',
#   'genre': 'Alternative Rock'},
#  {'number': '364',
#   'album': 'L.A. Woman',
#   'year': '1971',
#   'artist': 'The Doors',
#   'genre': 'Blues Rock, Classic Rock'},
#  {'number': '365',
#   'album': 'Rage Against the Machine',
#   'year': '1992',
#   'artist': 'Rage Against the Machine',
#   'genre': 'Funk Metal'},
#  {'number': '366',
#   'album': 'American Recordings',
#   'year': '1994',
#   'artist': 'Johnny Cash',
#   'genre': 'Country, Gospel, Folk'},
#  {'number': '367',
#   'album': 'Ray of Light',
#   'year': '1998',
#   'artist': 'Madonna',
#   'genre': 'House, Techno, Downtempo, Vocal, Ambient'},
#  {'number': '368',
#   'album': 'Eagles',
#   'year': '1972',
#   'artist': 'Eagles',
#   'genre': 'Country Rock, Classic Rock'},
#  {'number': '369',
#   'album': 'Louder Than Bombs',
#   'year': '1987',
#   'artist': 'The Smiths',
#   'genre': 'Alternative Rock, Indie Rock'},
#  {'number': '370',
#   'album': 'Mott',
#   'year': '1973',
#   'artist': 'Mott the Hoople',
#   'genre': 'Classic Rock'},
#  {'number': '371',
#   'album': "Whatever People Say I Am, That's What I'm Not",
#   'year': '2006',
#   'artist': 'Arctic Monkeys',
#   'genre': 'Indie Rock'},
#  {'number': '372',
#   'album': 'Reggatta de Blanc',
#   'year': '1979',
#   'artist': 'The Police',
#   'genre': 'New Wave, Pop Rock'},
#  {'number': '373',
#   'album': 'Volunteers',
#   'year': '1969',
#   'artist': 'Jefferson Airplane',
#   'genre': 'Psychedelic Rock, Folk Rock, Country Rock, Honky Tonk'},
#  {'number': '374',
#   'album': 'Siren',
#   'year': '1975',
#   'artist': 'Roxy Music',
#   'genre': 'Art Rock, Pop Rock, Glam'},
#  {'number': '375',
#   'album': 'Late for the Sky',
#   'year': '1974',
#   'artist': 'Jackson Browne',
#   'genre': 'Pop Rock'},
#  {'number': '376',
#   'album': 'Post',
#   'year': '1995',
#   'artist': 'Bjork',
#   'genre': 'Breakbeat, IDM, Electro'},
#  {'number': '378',
#   'album': "(What's the Story) Morning Glory?",
#   'year': '1995',
#   'artist': 'Oasis',
#   'genre': 'Brit Pop'},
#  {'number': '379',
#   'album': 'CrazySexyCool',
#   'year': '1994',
#   'artist': 'TLC',
#   'genre': 'RnB/Swing'},
#  {'number': '380',
#   'album': 'Funky Kingston',
#   'year': '1973',
#   'artist': 'Toots & The Maytals',
#   'genre': 'Reggae Gospel, Reggae, Roots Reggae, Rocksteady'},
#  {'number': '381',
#   'album': 'The Smile Sessions',
#   'year': '2011',
#   'artist': 'The Beach Boys',
#   'genre': 'Pop Rock, Psychedelic Rock'},
#  {'number': '382',
#   'album': 'The Modern Lovers',
#   'year': '1976',
#   'artist': 'The Modern Lovers',
#   'genre': 'Art Rock, Indie Rock'},
#  {'number': '383',
#   'album': 'More Songs About Buildings and Food',
#   'year': '1978',
#   'artist': 'Talking Heads',
#   'genre': 'New Wave, Indie Rock'},
#  {'number': '384',
#   'album': 'A Quick One',
#   'year': '1966',
#   'artist': 'The Who',
#   'genre': 'Mod, Beat, Psychedelic Rock'},
#  {'number': '385',
#   'album': '"Love and Theft"',
#   'year': '2001',
#   'artist': 'Bob Dylan',
#   'genre': 'Folk Rock, Blues Rock'},
#  {'number': '386',
#   'album': 'Pretzel Logic',
#   'year': '1974',
#   'artist': 'Steely Dan',
#   'genre': 'Jazz-Rock, Pop Rock, Classic Rock'},
#  {'number': '387',
#   'album': 'Enter the Wu Tang: 36 Chambers',
#   'year': '1993',
#   'artist': 'Wu Tang Clan',
#   'genre': 'Gangsta'},
#  {'number': '388',
#   'album': 'The Indestructible Beat of Soweto',
#   'year': '1985',
#   'artist': 'Various Artists',
#   'genre': 'African'},
#  {'number': '389',
#   'album': 'The End of the Innocence',
#   'year': '1989',
#   'artist': 'Don Henley',
#   'genre': 'Pop Rock'},
#  {'number': '390',
#   'album': 'Elephant',
#   'year': '2003',
#   'artist': 'The White Stripes',
#   'genre': 'Blues Rock, Garage Rock, Alternative Rock'},
#  {'number': '391',
#   'album': 'The Pretender',
#   'year': '1976',
#   'artist': 'Jackson Browne',
#   'genre': 'Soft Rock, Pop Rock'},
#  {'number': '392',
#   'album': 'Let It Be',
#   'year': '1970',
#   'artist': 'The Beatles',
#   'genre': 'Pop Rock'},
#  {'number': '393',
#   'album': 'Kala',
#   'year': '2007',
#   'artist': 'M.I.A.',
#   'genre': 'Grime, Bollywood, Hip Hop, Dancehall'},
#  {'number': '394',
#   'album': 'Good Old Boys',
#   'year': '1974',
#   'artist': 'Randy Newman',
#   'genre': 'Pop Rock, Vocal'},
#  {'number': '395',
#   'album': 'Sound of Silver',
#   'year': '2007',
#   'artist': 'LCD Soundsystem',
#   'genre': 'Leftfield, Alternative Rock, Electro, Disco'},
#  {'number': '396',
#   'album': 'For Your Pleasure',
#   'year': '1973',
#   'artist': 'Roxy Music',
#   'genre': 'Art Rock, Avantgarde, Glam'},
#  {'number': '397',
#   'album': 'Blue Lines',
#   'year': '1991',
#   'artist': 'Massive Attack',
#   'genre': 'Dub, Downtempo'},
#  {'number': '398',
#   'album': 'Eliminator',
#   'year': '1983',
#   'artist': 'ZZ Top',
#   'genre': 'Pop Rock'},
#  {'number': '399',
#   'album': 'Rain Dogs',
#   'year': '1985',
#   'artist': 'Tom Waits',
#   'genre': 'Blues Rock'},
#  {'number': '401',
#   'album': 'Californication',
#   'year': '1999',
#   'artist': 'Red Hot Chili Peppers',
#   'genre': 'Alternative Rock, Funk Metal'},
#  {'number': '402',
#   'album': 'Illmatic',
#   'year': '1994',
#   'artist': 'Nas',
#   'genre': 'None'},
#  {'number': '403',
#   'album': "(pronounced 'leh-'nerd 'skin-'nerd)",
#   'year': '1973',
#   'artist': 'Lynyrd Skynyrd',
#   'genre': 'Blues Rock, Hard Rock, Southern Rock'},
#  {'number': '404',
#   'album': "Dr. John's Gumbo",
#   'year': '1972',
#   'artist': 'Dr. John',
#   'genre': 'Bayou Funk, Funk, Rhythm & Blues'},
#  {'number': '405',
#   'album': 'Radio City',
#   'year': '1974',
#   'artist': 'Big Star',
#   'genre': 'Power Pop'},
#  {'number': '406',
#   'album': 'Rid of Me',
#   'year': '1993',
#   'artist': 'PJ Harvey',
#   'genre': 'Indie Rock'},
#  {'number': '407',
#   'album': 'Sandinista!',
#   'year': '1980',
#   'artist': 'The Clash',
#   'genre': 'Rock & Roll, Dub, Punk'},
#  {'number': '408',
#   'album': "I Do Not Want What I Haven't Got",
#   'year': '1989',
#   'artist': "Sinead O'Connor",
#   'genre': 'Blues Rock, Rhythm & Blues, Soul'},
#  {'number': '409',
#   'album': 'Strange Days',
#   'year': '1967',
#   'artist': 'The Doors',
#   'genre': 'Psychedelic Rock'},
#  {'number': '410',
#   'album': 'Time Out of Mind',
#   'year': '1997',
#   'artist': 'Bob Dylan',
#   'genre': 'Blues Rock'},
#  {'number': '411',
#   'album': '461 Ocean Boulevard',
#   'year': '1974',
#   'artist': 'Eric Clapton',
#   'genre': 'Blues Rock'},
#  {'number': '412',
#   'album': 'Pink Flag',
#   'year': '1977',
#   'artist': 'Wire',
#   'genre': 'Punk'},
#  {'number': '413',
#   'album': 'Double Nickels on the Dime',
#   'year': '1984',
#   'artist': 'Minutemen',
#   'genre': 'Alternative Rock, Hardcore, Punk'},
#  {'number': '414',
#   'album': 'Beauty and the Beat',
#   'year': '1981',
#   'artist': "The Go Go's",
#   'genre': 'Pop Rock'},
#  {'number': '415',
#   'album': 'Van Halen',
#   'year': '1978',
#   'artist': 'Van Halen',
#   'genre': 'Hard Rock'},
#  {'number': '416',
#   'album': 'Mule Variations',
#   'year': '1999',
#   'artist': 'Tom Waits',
#   'genre': 'Abstract, Art Rock'},
#  {'number': '417',
#   'album': 'Boy',
#   'year': '1980',
#   'artist': 'U2',
#   'genre': 'New Wave, Pop Rock'},
#  {'number': '418',
#   'album': 'Band on the Run',
#   'year': '1973',
#   'artist': 'Paul McCartney & Wings',
#   'genre': 'Pop Rock'},
#  {'number': '419',
#   'album': 'Dummy',
#   'year': '1994',
#   'artist': 'Portishead',
#   'genre': 'Trip Hop, Downtempo'},
#  {'number': '420',
#   'album': 'The "Chirping" Crickets',
#   'year': '1957',
#   'artist': 'The Crickets',
#   'genre': 'Rockabilly, Rock & Roll'},
#  {'number': '422',
#   'album': 'Presenting the Fabulous Ronettes Featuring Veronica',
#   'year': '1963',
#   'artist': 'The Ronettes',
#   'genre': 'Rock & Roll, Vocal'},
#  {'number': '423',
#   'album': 'Anthology',
#   'year': '2001',
#   'artist': 'Diana Ross & The Supremes',
#   'genre': 'Pop Rock, Soul, Disco'},
#  {'number': '424',
#   'album': 'The Rising',
#   'year': '2002',
#   'artist': 'Bruce Springsteen',
#   'genre': 'Folk Rock, Classic Rock'},
#  {'number': '425',
#   'album': 'Grievous Angel',
#   'year': '1974',
#   'artist': 'Gram Parsons',
#   'genre': 'Country Rock, Honky Tonk'},
#  {'number': '427',
#   'album': 'Sleepless',
#   'year': '2002',
#   'artist': 'Peter Wolf',
#   'genre': 'Blues Rock, Pop Rock, Ballad'},
#  {'number': '428',
#   'album': "Outlandos d'Amour",
#   'year': '1978',
#   'artist': 'The Police',
#   'genre': 'Alternative Rock, New Wave, Punk'},
#  {'number': '429',
#   'album': 'Another Green World',
#   'year': '1975',
#   'artist': 'Brian Eno',
#   'genre': 'Experimental, Ambient'},
#  {'number': '430',
#   'album': 'Vampire Weekend',
#   'year': '2007',
#   'artist': 'Vampire Weekend',
#   'genre': 'Indie Rock'},
#  {'number': '431',
#   'album': 'Stories From the City, Stories From the Sea',
#   'year': '2000',
#   'artist': 'PJ Harvey',
#   'genre': 'Indie Rock'},
#  {'number': '432',
#   'album': 'Here Come the Warm Jets',
#   'year': '1973',
#   'artist': 'Brian Eno',
#   'genre': 'Art Rock, Glam'},
#  {'number': '433',
#   'album': 'All Things Must Pass',
#   'year': '1970',
#   'artist': 'George Harrison',
#   'genre': 'Pop Rock'},
#  {'number': '434',
#   'album': '#1 Record',
#   'year': '1972',
#   'artist': 'Big Star',
#   'genre': 'Power Pop'},
#  {'number': '435',
#   'album': 'In Utero',
#   'year': '1993',
#   'artist': 'Nirvana',
#   'genre': 'Grunge, Alternative Rock'},
#  {'number': '436',
#   'album': 'Sea Change',
#   'year': '2002',
#   'artist': 'Beck',
#   'genre': 'Alternative Rock, Post Rock'},
#  {'number': '437',
#   'album': 'Tha Carter III',
#   'year': '2008',
#   'artist': 'Lil Wayne',
#   'genre': 'RnB/Swing, Screw, Pop Rap, Thug Rap'},
#  {'number': '438',
#   'album': "Boys Don't Cry",
#   'year': '1979',
#   'artist': 'The Cure',
#   'genre': 'New Wave, Post-Punk'},
#  {'number': '439',
#   'album': 'Live at the Harlem Square Club, 1963',
#   'year': '1985',
#   'artist': 'Sam Cooke',
#   'genre': 'Soul'},
#  {'number': '440',
#   'album': 'Rum Sodomy & the Lash',
#   'year': '1985',
#   'artist': 'The Pogues',
#   'genre': 'Folk Rock, Celtic, Punk'},
#  {'number': '441',
#   'album': 'Suicide',
#   'year': '1977',
#   'artist': 'Suicide',
#   'genre': 'New Wave, Experimental'},
#  {'number': '442',
#   'album': 'Q: Are We Not Men? A: We Are Devo!',
#   'year': '1978',
#   'artist': 'DEVO',
#   'genre': 'New Wave'},
#  {'number': '443',
#   'album': 'In Color',
#   'year': '1977',
#   'artist': 'Cheap Trick',
#   'genre': 'Power Pop, Pop Rock, Hard Rock'},
#  {'number': '444',
#   'album': 'The World Is a Ghetto',
#   'year': '1972',
#   'artist': 'War',
#   'genre': 'Funk'},
#  {'number': '445',
#   'album': 'Fly Like an Eagle',
#   'year': '1976',
#   'artist': 'Steve Miller Band',
#   'genre': 'Pop Rock'},
#  {'number': '446',
#   'album': 'Back in the USA',
#   'year': '1970',
#   'artist': 'MC5',
#   'genre': 'Garage Rock, Rock & Roll'},
#  {'number': '447',
#   'album': 'Getz / Gilberto',
#   'year': '1964',
#   'artist': 'Stan Getz/Joao Gilberto featuring Antonio Carlos Jobim',
#   'genre': 'Bossa Nova,Latin Jazz'},
#  {'number': '448',
#   'album': 'Synchronicity',
#   'year': '1983',
#   'artist': 'The Police',
#   'genre': 'New Wave, Pop Rock'},
#  {'number': '450',
#   'album': 'For Everyman',
#   'year': '1973',
#   'artist': 'Jackson Browne',
#   'genre': 'Pop Rock, Classic Rock'},
#  {'number': '451',
#   'album': 'Back to Black',
#   'year': '2006',
#   'artist': 'Amy Winehouse',
#   'genre': 'Soul'},
#  {'number': '452',
#   'album': 'John Prine',
#   'year': '1971',
#   'artist': 'John Prine',
#   'genre': 'Country, Folk'},
#  {'number': '453',
#   'album': 'Strictly Business',
#   'year': '1987',
#   'artist': 'EPMD',
#   'genre': 'None'},
#  {'number': '454',
#   'album': 'Love It to Death',
#   'year': '1971',
#   'artist': 'Alice Cooper',
#   'genre': 'Classic Rock'},
#  {'number': '455',
#   'album': 'How Will the Wolf Survive?',
#   'year': '1984',
#   'artist': 'Los Lobos',
#   'genre': 'Blues Rock'},
#  {'number': '456',
#   'album': 'Here, My Dear',
#   'year': '1978',
#   'artist': 'Marvin Gaye',
#   'genre': 'Soul'},
#  {'number': '457',
#   'album': 'Z',
#   'year': '2005',
#   'artist': 'My Morning Jacket',
#   'genre': 'Alternative Rock'},
#  {'number': '458',
#   'album': 'Tumbleweed Connection',
#   'year': '1970',
#   'artist': 'Elton John',
#   'genre': 'Soft Rock, Country Rock'},
#  {'number': '460',
#   'album': 'Live Through This',
#   'year': '1994',
#   'artist': 'Hole',
#   'genre': 'Grunge'},
#  {'number': '461',
#   'album': 'Metal Box',
#   'year': '1979',
#   'artist': 'Public Image Ltd.',
#   'genre': 'Post-Punk, Dub, Avantgarde, Experimental'},
#  {'number': '462',
#   'album': 'Document',
#   'year': '1987',
#   'artist': 'R.E.M.',
#   'genre': 'None'},
#  {'number': '463',
#   'album': 'Heaven Up Here',
#   'year': '1981',
#   'artist': 'Echo and The Bunnymen',
#   'genre': 'New Wave, Indie Rock'},
#  {'number': '464',
#   'album': 'Hysteria',
#   'year': '1987',
#   'artist': 'Def Leppard',
#   'genre': 'Hard Rock, Arena Rock'},
#  {'number': '465',
#   'album': '69 Love Songs',
#   'year': '1999',
#   'artist': 'The Magnetic Fields',
#   'genre': 'Synth-pop, Indie Rock'},
#  {'number': '466',
#   'album': 'A Rush of Blood to the Head',
#   'year': '2002',
#   'artist': 'Coldplay',
#   'genre': 'Alternative Rock, Pop Rock'},
#  {'number': '467',
#   'album': 'Tunnel of Love',
#   'year': '1987',
#   'artist': 'Bruce Springsteen',
#   'genre': 'None'},
#  {'number': '468',
#   'album': 'The Paul Butterfield Blues Band',
#   'year': '1965',
#   'artist': 'The Paul Butterfield Blues Band',
#   'genre': 'Blues Rock, Electric Blues, Chicago Blues, Modern Electric Blues, Harmonica Blues'},
#  {'number': '469',
#   'album': 'The Score',
#   'year': '1996',
#   'artist': 'Fugees',
#   'genre': 'Pop Rap, Conscious'},
#  {'number': '470',
#   'album': 'Radio',
#   'year': '1985',
#   'artist': 'L.L. Cool J',
#   'genre': 'None'},
#  {'number': '471',
#   'album': 'I Want to See the Bright Lights Tonight',
#   'year': '1974',
#   'artist': 'Richard & Linda Thompson',
#   'genre': 'Classic Rock, Folk Rock'},
#  {'number': '472',
#   'album': 'Faith',
#   'year': '1987',
#   'artist': 'George Michael',
#   'genre': 'Downtempo, Soft Rock, Pop Rock, Synth-pop'},
#  {'number': '473',
#   'album': 'The Smiths',
#   'year': '1984',
#   'artist': 'The Smiths',
#   'genre': 'Indie Rock'},
#  {'number': '474',
#   'album': 'Proxima estacion: Esperanza',
#   'year': '2001',
#   'artist': 'Manu Chao',
#   'genre': 'Folk Rock, Reggae, Reggae-Pop'},
#  {'number': '475',
#   'album': 'Armed Forces',
#   'year': '1979',
#   'artist': 'Elvis Costello & The Attractions',
#   'genre': 'New Wave, Pop Rock'},
#  {'number': '476',
#   'album': 'Life After Death',
#   'year': '1997',
#   'artist': 'The Notorious B.I.G.',
#   'genre': 'None'},
#  {'number': '477',
#   'album': 'Down Every Road',
#   'year': '1996',
#   'artist': 'Merle Haggard',
#   'genre': 'Country'},
#  {'number': '478',
#   'album': 'All Time Greatest Hits',
#   'year': '2002',
#   'artist': 'Loretta Lynn',
#   'genre': 'Country'},
#  {'number': '479',
#   'album': 'Maggot Brain',
#   'year': '1971',
#   'artist': 'Funkadelic',
#   'genre': 'P.Funk, Psychedelic Rock'},
#  {'number': '480',
#   'album': 'Only Built 4 Cuban Linx',
#   'year': '1995',
#   'artist': 'Raekwon',
#   'genre': 'None'},
#  {'number': '481',
#   'album': 'Voodoo',
#   'year': '2000',
#   'artist': "D'Angelo",
#   'genre': 'Soul, Funk, Neo Soul'},
#  {'number': '482',
#   'album': 'Guitar Town',
#   'year': '1986',
#   'artist': 'Steve Earle',
#   'genre': 'Country, Honky Tonk'},
#  {'number': '483',
#   'album': 'Entertainment!',
#   'year': '1979',
#   'artist': 'Gang of Four',
#   'genre': 'Post-Punk, New Wave'},
#  {'number': '484',
#   'album': 'All the Young Dudes',
#   'year': '1972',
#   'artist': 'Mott the Hoople',
#   'genre': 'Classic Rock, Glam'},
#  {'number': '485',
#   'album': 'Vitalogy',
#   'year': '1994',
#   'artist': 'Pearl Jam',
#   'genre': 'Alternative Rock, Hard Rock'},
#  {'number': '486',
#   'album': "That's the Way of the World",
#   'year': '1975',
#   'artist': 'Earth, Wind & Fire',
#   'genre': 'Soul, Funk, Disco'},
#  {'number': '487',
#   'album': "She's So Unusual",
#   'year': '1983',
#   'artist': 'Cyndi Lauper',
#   'genre': 'Pop Rock, Synth-pop'},
#  {'number': '488',
#   'album': 'New Day Rising',
#   'year': '1985',
#   'artist': 'Husker Du',
#   'genre': 'Alternative Rock, Hardcore, Punk'},
#  {'number': '489',
#   'album': 'Destroyer',
#   'year': '1976',
#   'artist': 'KISS',
#   'genre': 'Hard Rock'},
#  {'number': '490',
#   'album': 'Tres hombres',
#   'year': '1973',
#   'artist': 'ZZ Top',
#   'genre': 'Blues Rock, Classic Rock'},
#  {'number': '491',
#   'album': 'Born Under a Bad Sign',
#   'year': '1967',
#   'artist': 'Albert King',
#   'genre': 'Electric Blues, Rhythm & Blues, Soul'},
#  {'number': '492',
#   'album': 'Touch',
#   'year': '1983',
#   'artist': 'Eurythmics',
#   'genre': 'New Wave, Synth-pop'},
#  {'number': '493',
#   'album': 'Yankee Hotel Foxtrot',
#   'year': '2002',
#   'artist': 'Wilco',
#   'genre': 'Alternative Rock'},
#  {'number': '494',
#   'album': 'Oracular Spectacular',
#   'year': '2007',
#   'artist': 'MGMT',
#   'genre': 'Synth-pop, Indie Rock'},
#  {'number': '495',
#   'album': 'Give It Up',
#   'year': '1972',
#   'artist': 'Bonnie Raitt',
#   'genre': 'Blues Rock'},
#  {'number': '496',
#   'album': 'Boz Scaggs',
#   'year': '1969',
#   'artist': 'Boz Scaggs',
#   'genre': 'Pop Rock'},
#  {'number': '497',
#   'album': 'White Blood Cells',
#   'year': '2001',
#   'artist': 'The White Stripes',
#   'genre': 'Indie Rock, Alternative Rock, Blues Rock, Garage Rock'},
#  {'number': '498',
#   'album': 'The Stone Roses',
#   'year': '1989',
#   'artist': 'The Stone Roses',
#   'genre': 'Indie Rock'},
#  {'number': '499',
#   'album': 'Live in Cook County Jail',
#   'year': '1971',
#   'artist': 'B.B. King',
#   'genre': 'Electric Blues'},
#  {'number': '500',
#   'album': 'Aquemini',
#   'year': '1998',
#   'artist': 'OutKast',
#   'genre': 'Reggae, Gangsta, Soul, Conscious'}]

# %%
def find_name(name):
    finding = None
    for album in music:
        if album['album'].title() == name.title():
            return album
    return finding

print(find_name('sgt. pepper\'s lonely hearts club band'))
# Out:
# {'number': '1', 'album': "Sgt. Pepper's Lonely Hearts Club Band", 'year': '1967', 'artist': 'The Beatles', 'genre': 'Rock & Roll, Psychedelic Rock'}
